# %% [markdown]
# # 🚗 Driver Drowsiness Detection System
# ## Model Architecture: ResNet50 (Transfer Learning)
#
# This notebook implements a deep learning solution for detecting driver drowsiness using computer vision. The system is trained on an expanded dataset of **12,000 images** and utilizes **ResNet50** via transfer learning to achieve high accuracy and robustness.
#
# ### ✨ Key Upgrades & Features:
# - **Data Scaling & Augmentation**: Dynamic brightness and spatial augmentations to handle varying lighting conditions inside a vehicle.
# - **Hard Negative Mining**: Integration of **Categorical Focal Crossentropy loss** to significantly reduce False Positives and False Negatives.
# - **Advanced Fine-Tuning**: Strategic unfreezing of deep layers coupled with L2 Regularization and Learning Rate Schedulers.
#
# ---
# ### 📋 Complete Analysis Workflow Index
#
# #### Part 1: Dataset Understanding (Basic Check)
# 1. **Structure & Distribution**: Counting images per class/split.
# 2. **Resolution & Color**: Verifying dimensions and channel counts.
#
# #### Part 2: Detailed EDA
# 3. **Visual EDA**: Inspecting samples, face visibility, and variations.
# 4. **Statistical EDA**: Pixel distributions, brightness, and blur detection.
#
# #### Part 3: Feature Encoding
# 5. **Label Encoding**: Converting text labels to Binary (0/1) and One-Hot vectors.
#
# #### Part 4: Data Preprocessing
# 6. **Resizing & Normalization**: Standardizing to 224x224 and scaling pixel values.
# 7. **Data Augmentation**: Enhancing dataset variety.
#
# #### Part 5: Dataset Splitting & Loading
# 8. **Generators**: Loading Train/Val/Test splits (70/15/15 ratio).
#
# #### Part 6: Model Building & Architecture
# 9. **Model Preparation**: Building ResNet50 base with custom classification head.
#
# #### Part 7: Model Training
# 10. **Phase 1 Training**: Training Classification Head.
# 11. **Phase 2 Fine-Tuning**: Deep layer unfreezing and training with low LR.
#
# #### Part 8: Model Evaluation & Interpretation
# 12. **Evaluation Metrics**: Precision, Recall, F1, Accuracy.
# 13. **Confusion Matrix**: Visualizing misclassifications and analyzing Failed Cases.
#
# #### Part 9: Exporting
# 14. **Keras & TFLite**: Saving models for production and edge deployment (Raspberry Pi/Mobile).

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import pandas as pd
import pickle
import tensorflow as tf
from collections import Counter
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, Flatten, Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Output Style
plt.style.use('ggplot')

# Define paths
BASE_DIR = Path(r"c:\Users\SAHAN\Desktop\CNN\Processed_Dataset")
TRAIN_DIR = BASE_DIR / "train"
VAL_DIR = BASE_DIR / "val"
TEST_DIR = BASE_DIR / "test"

CATEGORIES = ["drowsy", "non-drowsy"]
TARGET_SIZE = (224, 224)
BATCH_SIZE = 32

# %% [markdown]
# # Part 1: Dataset Understanding

# %%
stats = []

for split in ["train", "val", "test"]:
    for category in CATEGORIES:
        folder = BASE_DIR / split / category
        count = len(list(folder.glob("*")))
        stats.append({
            "Split": split,
            "Category": category,
            "Count": count
        })

df_stats = pd.DataFrame(stats)
print("Dataset Statistics:")
print(df_stats)

# Visualize
df_stats.pivot(index="Split", columns="Category", values="Count").plot(kind="bar", stacked=True, figsize=(10, 6))
plt.title("Image Distribution per Split")
plt.ylabel("Number of Images")
plt.show()
# Out:
# Dataset Statistics:
#    Split    Category  Count
# 0  train      drowsy   4200
# 1  train  non-drowsy   4200
# 2    val      drowsy    900
# 3    val  non-drowsy    900
# 4   test      drowsy    900
# 5   test  non-drowsy    900

# %% [markdown]
# ## 1.2 Image Resolution and Color Space Analysis

# %%
# Sample analysis (iterating through training set)
resolutions = []
channels = []
print("Scanning the entire dataset for property check...")

sample_count = 0
for category in CATEGORIES:
    folder = TRAIN_DIR / category
    for img_path in folder.glob("*"):
        # if sample_count >= 12000: break
        img = cv2.imread(str(img_path))
        if img is not None:
            resolutions.append(img.shape[:2])
            channels.append(img.shape[2] if len(img.shape) > 2 else 1)
            sample_count += 1

print(f"Resolution Check: {Counter([str(r) for r in resolutions])}")
print(f"Channel Check (OpenCV loads): {Counter(channels)}")
# Out:
# Scanning the entire dataset for property check...
# Resolution Check: Counter({'(224, 224)': 8400})
# Channel Check (OpenCV loads): Counter({3: 8400})

# %% [markdown]
# # Part 2: Detailed Exploratory Data Analysis (EDA)

# %%
def clean_filename_info(filename):
    has_glasses = "with_glasses" in filename
    origin = "BW" if "Black&White" in filename else "Color"
    return origin, has_glasses

def view_grid(category, samples=5):
    folder = TRAIN_DIR / category
    all_files = list(folder.glob("*"))
    selected = np.random.choice(all_files, samples, replace=False)
    
    plt.figure(figsize=(15, 4))
    plt.suptitle(f"Class: {category.upper()}", fontsize=14)
    
    for i, path in enumerate(selected):
        img = cv2.imread(str(path))
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        origin, glasses = clean_filename_info(path.name)
        plt.subplot(1, samples, i+1)
        plt.imshow(img, cmap='gray' if origin=='BW' else None)
        plt.axis('off')
        plt.title(f"{origin} | {'Glasses' if glasses else 'No Glass'}", fontsize=10)
    plt.show()

view_grid("drowsy", 6)
view_grid("non-drowsy", 6)

# %% [markdown]
# ## 2.1 Statistical Plot: Brightness Distribution
# Checking if there is a significant lighting difference between Drowsy and Non-Drowsy classes.

# %%
brightness_values = {"drowsy": [], "non-drowsy": []}

print("Calculating brightness stats for the entire dataset...")
for category in CATEGORIES:
    folder = TRAIN_DIR / category
    for i, img_path in enumerate(folder.glob("*")):
        # if i >= 12000: break
        img = cv2.imread(str(img_path))
        if img is not None:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            brightness_values[category].append(np.mean(gray))

plt.figure(figsize=(10, 5))
sns.kdeplot(brightness_values["drowsy"], fill=True, label="Drowsy", color="red")
sns.kdeplot(brightness_values["non-drowsy"], fill=True, label="Non-Drowsy", color="blue")
plt.title("Brightness Distribution Analysis")
plt.xlabel("Average Pixel Intensity (Brightness)")
plt.legend()
plt.show()
# Out:
# Calculating brightness stats for the entire dataset...

# %%
# Gather Metadata
data = []
for category in ["drowsy", "non-drowsy"]:
    folder = TRAIN_DIR / category
    for filepath in folder.glob("*"):
        origin, has_glasses = clean_filename_info(filepath.name)
        data.append({"category": category, "has_glasses": has_glasses})

df = pd.DataFrame(data)
summary = df.groupby(["category", "has_glasses"]).size().reset_index(name="count")
print("Sub-category Distribution in Train Set:")
print(summary)
# Out:
# Sub-category Distribution in Train Set:
#      category  has_glasses  count
# 0      drowsy        False   2095
# 1      drowsy         True   2105
# 2  non-drowsy        False   2122
# 3  non-drowsy         True   2078

# %% [markdown]
# # Part 3: Feature Encoding (Enhanced)

# %%
labels = ["drowsy", "non-drowsy"]
label_map = {label: i for i, label in enumerate(labels)}
print(f"Binary Mapping: {label_map}")

# 1. Visualizing One-Hot Vectors Table
demo_encoding = pd.DataFrame({
    'Class': ['drowsy', 'non-drowsy'],
    'Binary': [0, 1],
    'One-Hot': [str(to_categorical(0, 2)), str(to_categorical(1, 2))]
})
print("\nEncoding Reference Table:")
print(demo_encoding)

# 2. Visualizing Class Balance using Encoded Labels
train_drowsy_count = len(list((TRAIN_DIR / "drowsy").glob("*")))
train_non_drowsy_count = len(list((TRAIN_DIR / "non-drowsy").glob("*")))

plt.figure(figsize=(6, 4))
plt.bar(['Label 0 (Drowsy)', 'Label 1 (Non-Drowsy)'], 
        [train_drowsy_count, train_non_drowsy_count], 
        color=['salmon', 'skyblue'])
plt.title("Class Balance by Encoded Label (Training Set)")
plt.ylabel("Count")
plt.show()
# Out:
# Binary Mapping: {'drowsy': 0, 'non-drowsy': 1}
#
# Encoding Reference Table:
#         Class  Binary  One-Hot
# 0      drowsy       0  [1. 0.]
# 1  non-drowsy       1  [0. 1.]

# %%
# 3. Sample Images with Vector Labels
plt.figure(figsize=(12, 4))
plt.suptitle("Data as Seen by Model: Image + One-Hot Vector", fontsize=14)

for i, category in enumerate(CATEGORIES):
    folder = TRAIN_DIR / category
    img_path = list(folder.glob("*"))[0]
    img = cv2.imread(str(img_path))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    encoded_label = to_categorical(label_map[category], num_classes=2)
    
    plt.subplot(1, 2, i+1)
    plt.imshow(img, cmap='gray' if "Black" in str(img_path) else None)
    plt.title(f"Class: {category}\nVector: {encoded_label}")
    plt.axis('off')
plt.show()

# %% [markdown]
# # Part 4: Data Preprocessing & Visualization

# %%
# Setup Generators with ResNet50 Preprocessing (Correct for Transfer Learning)
from tensorflow.keras.applications.resnet50 import preprocess_input

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input, # Scales to [-1, 1]
    rotation_range=20,       # Rotation
    width_shift_range=0.2,   # Horizontal Shift
    height_shift_range=0.2,  # Vertical Shift
    zoom_range=0.2,          # Zoom
    brightness_range=[0.8, 1.2], # Added brightness range to handle lighting variations
    horizontal_flip=True,    # Flip
    fill_mode='nearest'      
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

print("Augmentation Configuration Set (ResNet50 [-1, 1]).")
# Out:
# Augmentation Configuration Set (ResNet50 [-1, 1]).

# %% [markdown]
# ## 4.1 Visualize Augmentation Effects
# Checking how "Rotation", "Zoom", and "Shift" actually affect our images.

# %%
def visualize_augmentation(category):
    # Pick a random image
    folder = TRAIN_DIR / category
    img_path = list(folder.glob("*"))[0]
    img = load_img(str(img_path), target_size=TARGET_SIZE)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    plt.figure(figsize=(15, 6))
    plt.suptitle(f"Augmentation Random Samples: {category.upper()}", fontsize=16)

    # Plot Original
    plt.subplot(2, 4, 1)
    plt.imshow(img)
    plt.title("Original")
    plt.axis('off')

    # Plot Augmented Versions
    for batch in train_datagen.flow(x, batch_size=1):
        plt.subplot(2, 4, i + 2)
        img_aug = batch[0] 
        # Rescale back to 0-1 for visualization if needed (resnet is -1 to 1)
        img_viz = img_aug - np.min(img_aug)
        img_viz = img_viz / (np.max(img_viz) + 1e-5)
        plt.imshow(img_viz)
        plt.title(f"Augment {i+1}")
        plt.axis('off')
        i += 1
        if i >= 7: break
    plt.show()

visualize_augmentation("drowsy")

# %% [markdown]
# ## 4.2 Using ResNet50 Preprocessing
# Note: The values have been mean-centered with respect to the ImageNet dataset using BGR format, which is the specific standard constraint required for ResNet50.

# %%
# Preprocessing Analysis
sample_path = list((TRAIN_DIR / "drowsy").glob("*"))[0]
original_img = cv2.imread(str(sample_path))
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

# Apply Preprocessing manually
preprocessed_img = cv2.resize(original_img, TARGET_SIZE)
preprocessed_img = preprocessed_img.astype("float32")
preprocessed_img = preprocess_input(preprocessed_img) # [-1, 1]

plt.figure(figsize=(12, 5))

# 1. Pixel Value Histogram (Normalization Check)
plt.subplot(1, 2, 1)
sns.histplot(original_img.flatten(), color='red', label='Original (0-255)', kde=True, stat="density", alpha=0.3)
sns.histplot(preprocessed_img.flatten(), color='blue', label='Preprocessed (-1 to 1)', kde=True, stat="density", alpha=0.3)
plt.title("Pixel Intensity Distribution Check")
plt.legend()

# 2. Input Tensor Heatmap (What the CNN 'sees' in shape)
plt.subplot(1, 2, 2)
heatmap_img = np.mean(preprocessed_img, axis=2)
sns.heatmap(heatmap_img, cmap="viridis", cbar=True)
plt.title("Input Tensor Heatmap (Mean Channel)")
plt.axis('off')

plt.show()

# %% [markdown]
# # Part 5: Dataset Splitting & Loading (Enhanced)

# %%
print("Loading Data from Directory Structure...")

# 1. Load Training Set
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# 2. Load Validation Set
validation_generator = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False 
)

# 3. Load Test Set
test_generator = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"\nClass Indices: {train_generator.class_indices}")
# Out:
# Loading Data from Directory Structure...
# Found 8400 images belonging to 2 classes.
# Found 1800 images belonging to 2 classes.
# Found 1800 images belonging to 2 classes.
#
# Class Indices: {'drowsy': 0, 'non-drowsy': 1}

# %% [markdown]
# ## 5.1 Visualize Generator Output (Batch Verification)

# %%
# Fetch a batch
x_batch, y_batch = next(train_generator)

# Visualize 8 random images from the batch
plt.figure(figsize=(15, 8))
plt.suptitle("Generator Batch Visualization (Correct Labels?)", fontsize=16)

class_names = list(train_generator.class_indices.keys())

for i in range(8):
    plt.subplot(2, 4, i+1)
    # Convert back to 0-1 for display
    img_disp = x_batch[i] - np.min(x_batch[i])
    img_disp = img_disp / (np.max(img_disp) + 1e-5)
    plt.imshow(img_disp)
    
    # Decode One-Hot Label
    label_idx = np.argmax(y_batch[i])
    label_name = class_names[label_idx]
    
    plt.title(f"Label: {label_name}\n{y_batch[i]}")
    plt.axis('off')
plt.show()

# %% [markdown]
# ## 5.2 Split Distribution Visualization

# %%
counts = [train_generator.samples, validation_generator.samples, test_generator.samples]
labels = [f'Train ({counts[0]})', f'Val ({counts[1]})', f'Test ({counts[2]})']
colors = ['#ff9999', '#66b3ff', '#99ff99']

plt.figure(figsize=(7, 7))
plt.pie(counts, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, explode=(0.05, 0, 0))
plt.title("Final Dataset Split Distribution")
plt.show()

# %% [markdown]
# # Part 6: Model Architecture & Transfer Learning Setup

# %%
from tensorflow.keras.regularizers import l2
def build_resnet_model(input_shape=(224, 224, 3), num_classes=2):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x) 
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

model = build_resnet_model()
INIT_LR = 1e-4
opt = Adam(learning_rate=INIT_LR)
model.compile(loss=CategoricalFocalCrossentropy(), optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ## 6.1 Visualize Model Complexity
# Visualizing the parameters per layer to understand the model structure.

# %%
# Visualizing Transfer Learning Layers
layer_names = []
layer_params = []

for layer in model.layers:
    layer_names.append(layer.name)
    layer_params.append(layer.count_params())

# Show only top 10 heaviest layers + last 3 custom layers
indices = np.argsort(layer_params)[-10:]
sorted_names = [layer_names[i] for i in indices]
sorted_params = [layer_params[i] for i in indices]

# Add Custom Head
custom_names = [l.name for l in model.layers[-3:]]
custom_params = [l.count_params() for l in model.layers[-3:]]

plt.figure(figsize=(12, 6))
plt.barh(sorted_names + custom_names, sorted_params + custom_params, color='purple')
plt.xlabel("Number of Parameters")
plt.title("Model Complexity: Top Layers + Custom Head")
plt.grid(axis='x')
plt.show()

print(f"Total Parameters: {model.count_params():,}")
print(f"Trainable Parameters: {np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Total Parameters: 23,850,242
# Trainable Parameters: 262,530

# %% [markdown]
# # Part 7: Hard Negative Mining & Model Training (With Fine-Tuning)

# %%
# --- TRAINING PHASE 1: Train Head Only ---
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=12,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2,
    patience=3, 
    min_lr=1e-6,
    verbose=1
)

from sklearn.utils import class_weight
# --- TRAINING PHASE 1: Train Head Only ---
print("Starting Training Phase 1 (Head Only)...")
# NEW: Compute class weights to handle dataset imbalance
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights_dict = dict(enumerate(class_weights))
print(f"Computed Class Weights: {class_weights_dict}")
history_1 = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    epochs=10, # Initial training
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights_dict # <--- NEW: Pass calculated weights to the model
)

# --- TRAINING PHASE 2: Fine-Tuning ---
print("\nStarting Training Phase 2 (Fine-Tuning)...")
# 1. Unfreeze the base model
model.trainable = True
# 2. Freeze earlier layers 
# NEW: Increased frozen layers from 100 to 120 to reduce overfitting during fine-tuning
FINE_TUNE_AT = 140
for layer in model.layers[:FINE_TUNE_AT]:
    layer.trainable = False
print(f"Layers frozen: {FINE_TUNE_AT}. Layers trainable: {len(model.layers) - FINE_TUNE_AT}")
# 3. Re-compile with label smoothing and very low learning rate
model.compile(
    loss=CategoricalFocalCrossentropy(), # <--- NEW: Re-applied label smoothing
    optimizer=Adam(learning_rate=1e-5), 
    metrics=["accuracy"]
)
# 4. Continue Training
total_epochs = 100 # 30 + 20
history_fine = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    initial_epoch=history_1.epoch[-1],
    epochs=total_epochs,
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights_dict # <--- NEW: Pass class weights to fine-tuning phase as well
)
print("Training Completed (Fine-Tuning).")

# Merge Histories for Plotting
acc = history_1.history['accuracy'] + history_fine.history['accuracy']
val_acc = history_1.history['val_accuracy'] + history_fine.history['val_accuracy']
loss = history_1.history['loss'] + history_fine.history['loss']
val_loss = history_1.history['val_loss'] + history_fine.history['val_loss']

# Create a dummy history object wrapper for compatibility with downstream plotting code
class CombinedHistory:
    def __init__(self):
        self.history = {
            'accuracy': acc,
            'val_accuracy': val_acc,
            'loss': loss,
            'val_loss': val_loss
        }
history = CombinedHistory()
# Out:
# Starting Training Phase 1 (Head Only)...
# Computed Class Weights: {0: np.float64(1.0), 1: np.float64(1.0)}
# C:\Users\SAHAN\AppData\Roaming\Python\Python313\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 281s 1s/step - accuracy: 0.6625 - loss: 1.6658 - val_accuracy: 0.7740 - val_loss: 1.0128 - learning_rate: 1.0000e-04
# Epoch 2/10
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 3:45 865ms/step - accuracy: 0.6875 - loss: 1.0161
# C:\Users\SAHAN\AppData\Roaming\Python\Python313\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 50s 188ms/step - accuracy: 0.6875 - loss: 1.0161 - val_accuracy: 0.7762 - val_loss: 1.0092 - learning_rate: 1.0000e-04
# Epoch 3/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 291s 1s/step - accuracy: 0.7804 - loss: 0.6706 - val_accuracy: 0.8438 - val_loss: 0.4190 - learning_rate: 1.0000e-04
# Epoch 4/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 181ms/step - accuracy: 0.8125 - loss: 0.4231 - val_accuracy: 0.8438 - val_loss: 0.4181 - learning_rate: 1.0000e-04
# Epoch 5/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.8190 - loss: 0.2961 - val_accuracy: 0.8828 - val_loss: 0.2000 - learning_rate: 1.0000e-04
# Epoch 6/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.8125 - loss: 0.2025 - val_accuracy: 0.8800 - val_loss: 0.1996 - learning_rate: 1.0000e-04
# Epoch 7/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.8433 - loss: 0.1553 - val_accuracy: 0.8398 - val_loss: 0.1161 - learning_rate: 1.0000e-04
# Epoch 8/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 178ms/step - accuracy: 0.8125 - loss: 0.1200 - val_accuracy: 0.8398 - val_loss: 0.1157 - learning_rate: 1.0000e-04
# Epoch 9/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.8613 - loss: 0.0950 - val_accuracy: 0.8973 - val_loss: 0.0735 - learning_rate: 1.0000e-04
# Epoch 10/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.9375 - loss: 0.0736 - val_accuracy: 0.8906 - val_loss: 0.0738 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 9.
#
# Starting Training Phase 2 (Fine-Tuning)...
# Layers frozen: 140. Layers trainable: 39
# Epoch 10/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.8867 - loss: 0.0727 - val_accuracy: 0.9107 - val_loss: 0.0677 - learning_rate: 1.0000e-05
# Epoch 11/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 177ms/step - accuracy: 0.8750 - loss: 0.0737 - val_accuracy: 0.9118 - val_loss: 0.0677 - learning_rate: 1.0000e-05
# Epoch 12/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.8924 - loss: 0.0683 - val_accuracy: 0.9085 - val_loss: 0.0640 - learning_rate: 1.0000e-05
# Epoch 13/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.9062 - loss: 0.0651 - val_accuracy: 0.9096 - val_loss: 0.0640 - learning_rate: 1.0000e-05
# Epoch 14/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.8945 - loss: 0.0645 - val_accuracy: 0.9079 - val_loss: 0.0608 - learning_rate: 1.0000e-05
# Epoch 15/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 0.9375 - loss: 0.0598 - val_accuracy: 0.9085 - val_loss: 0.0607 - learning_rate: 1.0000e-05
# Epoch 16/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.8929 - loss: 0.0619 - val_accuracy: 0.9040 - val_loss: 0.0587 - learning_rate: 1.0000e-05
# Epoch 17/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.9062 - loss: 0.0604 - val_accuracy: 0.9018 - val_loss: 0.0587 - learning_rate: 1.0000e-05
# Epoch 18/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.9024 - loss: 0.0588 - val_accuracy: 0.9057 - val_loss: 0.0560 - learning_rate: 1.0000e-05
# Epoch 19/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.8125 - loss: 0.0584 - val_accuracy: 0.9057 - val_loss: 0.0560 - learning_rate: 1.0000e-05
# Epoch 20/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.8994 - loss: 0.0565 - val_accuracy: 0.9275 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 21/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9062 - loss: 0.0540 - val_accuracy: 0.9269 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 22/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.9098 - loss: 0.0540 - val_accuracy: 0.9258 - val_loss: 0.0507 - learning_rate: 1.0000e-05
# Epoch 23/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 49s 186ms/step - accuracy: 0.9062 - loss: 0.0571 - val_accuracy: 0.9263 - val_loss: 0.0506 - learning_rate: 1.0000e-05
# Epoch 24/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.9093 - loss: 0.0520 - val_accuracy: 0.9280 - val_loss: 0.0489 - learning_rate: 1.0000e-05
# Epoch 25/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.9375 - loss: 0.0482 - val_accuracy: 0.9269 - val_loss: 0.0489 - learning_rate: 1.0000e-05
# Epoch 26/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 277s 1s/step - accuracy: 0.9112 - loss: 0.0498 - val_accuracy: 0.9302 - val_loss: 0.0471 - learning_rate: 1.0000e-05
# Epoch 27/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 179ms/step - accuracy: 0.9375 - loss: 0.0472 - val_accuracy: 0.9291 - val_loss: 0.0471 - learning_rate: 1.0000e-05
# Epoch 28/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.9086 - loss: 0.0485 - val_accuracy: 0.9185 - val_loss: 0.0457 - learning_rate: 1.0000e-05
# Epoch 29/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 0.9062 - loss: 0.0447 - val_accuracy: 0.9185 - val_loss: 0.0457 - learning_rate: 1.0000e-05
# Epoch 30/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 277s 1s/step - accuracy: 0.9093 - loss: 0.0465 - val_accuracy: 0.9135 - val_loss: 0.0445 - learning_rate: 1.0000e-05
# Epoch 31/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 179ms/step - accuracy: 0.8750 - loss: 0.0486 - val_accuracy: 0.9141 - val_loss: 0.0444 - learning_rate: 1.0000e-05
# Epoch 32/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.9114 - loss: 0.0454 - val_accuracy: 0.9180 - val_loss: 0.0428 - learning_rate: 1.0000e-05
# Epoch 33/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 1.0000 - loss: 0.0362 - val_accuracy: 0.9185 - val_loss: 0.0429 - learning_rate: 1.0000e-05
# Epoch 34/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 428s 2s/step - accuracy: 0.9135 - loss: 0.0437 - val_accuracy: 0.9314 - val_loss: 0.0411 - learning_rate: 1.0000e-05
# Epoch 35/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 84s 315ms/step - accuracy: 0.8438 - loss: 0.0463 - val_accuracy: 0.9330 - val_loss: 0.0411 - learning_rate: 1.0000e-05
# Epoch 36/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 514s 2s/step - accuracy: 0.9140 - loss: 0.0426 - val_accuracy: 0.9224 - val_loss: 0.0404 - learning_rate: 1.0000e-05
# Epoch 37/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 86s 324ms/step - accuracy: 0.8750 - loss: 0.0396 - val_accuracy: 0.9224 - val_loss: 0.0403 - learning_rate: 1.0000e-05
# Epoch 38/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 475s 2s/step - accuracy: 0.9169 - loss: 0.0411 - val_accuracy: 0.9269 - val_loss: 0.0390 - learning_rate: 1.0000e-05
# Epoch 39/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 82s 312ms/step - accuracy: 0.8438 - loss: 0.0452 - val_accuracy: 0.9280 - val_loss: 0.0390 - learning_rate: 1.0000e-05
# Epoch 40/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - accuracy: 0.9137 - loss: 0.0402 - val_accuracy: 0.9308 - val_loss: 0.0379 - learning_rate: 1.0000e-05
# Epoch 41/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 83s 314ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 0.9319 - val_loss: 0.0379 - learning_rate: 1.0000e-05
# Epoch 42/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.9209 - loss: 0.0390 - val_accuracy: 0.9319 - val_loss: 0.0368 - learning_rate: 1.0000e-05
# Epoch 43/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 0.9688 - loss: 0.0355 - val_accuracy: 0.9325 - val_loss: 0.0368 - learning_rate: 1.0000e-05
# Epoch 44/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 292s 1s/step - accuracy: 0.9169 - loss: 0.0381 - val_accuracy: 0.9330 - val_loss: 0.0359 - learning_rate: 1.0000e-05
# Epoch 45/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 50s 189ms/step - accuracy: 0.9375 - loss: 0.0391 - val_accuracy: 0.9342 - val_loss: 0.0359 - learning_rate: 1.0000e-05
# Epoch 46/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.9208 - loss: 0.0370 - val_accuracy: 0.9364 - val_loss: 0.0349 - learning_rate: 1.0000e-05
# Epoch 47/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 181ms/step - accuracy: 0.9062 - loss: 0.0414 - val_accuracy: 0.9358 - val_loss: 0.0350 - learning_rate: 1.0000e-05
# Epoch 48/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9215 - loss: 0.0363 - val_accuracy: 0.9325 - val_loss: 0.0343 - learning_rate: 1.0000e-05
# Epoch 49/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 175ms/step - accuracy: 0.8750 - loss: 0.0376 - val_accuracy: 0.9319 - val_loss: 0.0343 - learning_rate: 1.0000e-05
# Epoch 50/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.9211 - loss: 0.0353 - val_accuracy: 0.9308 - val_loss: 0.0336 - learning_rate: 1.0000e-05
# Epoch 51/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9062 - loss: 0.0362 - val_accuracy: 0.9308 - val_loss: 0.0336 - learning_rate: 1.0000e-05
# Epoch 52/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.9203 - loss: 0.0346 - val_accuracy: 0.9358 - val_loss: 0.0326 - learning_rate: 1.0000e-05
# Epoch 53/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 49s 185ms/step - accuracy: 0.9375 - loss: 0.0342 - val_accuracy: 0.9358 - val_loss: 0.0326 - learning_rate: 1.0000e-05
# Epoch 54/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.9221 - loss: 0.0338 - val_accuracy: 0.9414 - val_loss: 0.0316 - learning_rate: 1.0000e-05
# Epoch 55/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 182ms/step - accuracy: 0.9688 - loss: 0.0302 - val_accuracy: 0.9392 - val_loss: 0.0317 - learning_rate: 1.0000e-05
# Epoch 56/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.9228 - loss: 0.0331 - val_accuracy: 0.9375 - val_loss: 0.0312 - learning_rate: 1.0000e-05
# Epoch 57/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9375 - loss: 0.0313 - val_accuracy: 0.9381 - val_loss: 0.0312 - learning_rate: 1.0000e-05
# Epoch 58/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9252 - loss: 0.0323 - val_accuracy: 0.9403 - val_loss: 0.0303 - learning_rate: 1.0000e-05
# Epoch 59/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 178ms/step - accuracy: 0.9375 - loss: 0.0294 - val_accuracy: 0.9414 - val_loss: 0.0303 - learning_rate: 1.0000e-05
# Epoch 60/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - accuracy: 0.9270 - loss: 0.0315 - val_accuracy: 0.9464 - val_loss: 0.0296 - learning_rate: 1.0000e-05
# Epoch 61/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 178ms/step - accuracy: 0.9062 - loss: 0.0354 - val_accuracy: 0.9459 - val_loss: 0.0296 - learning_rate: 1.0000e-05
# Epoch 62/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.9326 - loss: 0.0308 - val_accuracy: 0.9386 - val_loss: 0.0292 - learning_rate: 1.0000e-05
# Epoch 63/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 178ms/step - accuracy: 0.8750 - loss: 0.0353 - val_accuracy: 0.9381 - val_loss: 0.0292 - learning_rate: 1.0000e-05
# Epoch 64/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9296 - loss: 0.0302 - val_accuracy: 0.9353 - val_loss: 0.0287 - learning_rate: 1.0000e-05
# Epoch 65/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 181ms/step - accuracy: 0.8125 - loss: 0.0404 - val_accuracy: 0.9336 - val_loss: 0.0288 - learning_rate: 1.0000e-05
# Epoch 66/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9261 - loss: 0.0301 - val_accuracy: 0.9386 - val_loss: 0.0283 - learning_rate: 1.0000e-05
# Epoch 67/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9375 - loss: 0.0262 - val_accuracy: 0.9358 - val_loss: 0.0284 - learning_rate: 1.0000e-05
# Epoch 68/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9328 - loss: 0.0292 - val_accuracy: 0.9381 - val_loss: 0.0279 - learning_rate: 1.0000e-05
# Epoch 69/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 177ms/step - accuracy: 0.9688 - loss: 0.0290 - val_accuracy: 0.9381 - val_loss: 0.0279 - learning_rate: 1.0000e-05
# Epoch 70/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.9334 - loss: 0.0286 - val_accuracy: 0.9414 - val_loss: 0.0270 - learning_rate: 1.0000e-05
# Epoch 71/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 49s 185ms/step - accuracy: 0.9375 - loss: 0.0214 - val_accuracy: 0.9414 - val_loss: 0.0270 - learning_rate: 1.0000e-05
# Epoch 72/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9371 - loss: 0.0281 - val_accuracy: 0.9420 - val_loss: 0.0264 - learning_rate: 1.0000e-05
# Epoch 73/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9375 - loss: 0.0271 - val_accuracy: 0.9414 - val_loss: 0.0265 - learning_rate: 1.0000e-05
# Epoch 74/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 393s 2s/step - accuracy: 0.9326 - loss: 0.0277 - val_accuracy: 0.9414 - val_loss: 0.0260 - learning_rate: 1.0000e-05
# Epoch 75/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 84s 318ms/step - accuracy: 0.9062 - loss: 0.0293 - val_accuracy: 0.9397 - val_loss: 0.0259 - learning_rate: 1.0000e-05
# Epoch 76/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.9346 - loss: 0.0273 - val_accuracy: 0.9425 - val_loss: 0.0257 - learning_rate: 1.0000e-05
# Epoch 77/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 179ms/step - accuracy: 0.9062 - loss: 0.0289 - val_accuracy: 0.9425 - val_loss: 0.0257 - learning_rate: 1.0000e-05
# Epoch 78/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 417s 2s/step - accuracy: 0.9321 - loss: 0.0270 - val_accuracy: 0.9336 - val_loss: 0.0262 - learning_rate: 1.0000e-05
# Epoch 79/100
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 3:40 846ms/step - accuracy: 0.9688 - loss: 0.0228
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.9688 - loss: 0.0228 - val_accuracy: 0.9336 - val_loss: 0.0261 - learning_rate: 1.0000e-05
# Epoch 80/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.9337 - loss: 0.0264 - val_accuracy: 0.9420 - val_loss: 0.0252 - learning_rate: 2.0000e-06
# Epoch 81/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 51s 193ms/step - accuracy: 0.9375 - loss: 0.0262 - val_accuracy: 0.9420 - val_loss: 0.0253 - learning_rate: 2.0000e-06
# Epoch 82/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.9374 - loss: 0.0262 - val_accuracy: 0.9336 - val_loss: 0.0255 - learning_rate: 2.0000e-06
# Epoch 83/100
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 4:03 933ms/step - accuracy: 0.8438 - loss: 0.0357
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1e-06.
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 182ms/step - accuracy: 0.8438 - loss: 0.0357 - val_accuracy: 0.9336 - val_loss: 0.0255 - learning_rate: 2.0000e-06
# Epoch 84/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 286s 1s/step - accuracy: 0.9377 - loss: 0.0262 - val_accuracy: 0.9448 - val_loss: 0.0250 - learning_rate: 1.0000e-06
# Epoch 85/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 50s 188ms/step - accuracy: 0.9062 - loss: 0.0255 - val_accuracy: 0.9442 - val_loss: 0.0250 - learning_rate: 1.0000e-06
# Epoch 86/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 384s 1s/step - accuracy: 0.9344 - loss: 0.0262 - val_accuracy: 0.9448 - val_loss: 0.0250 - learning_rate: 1.0000e-06
# Epoch 87/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 0.9062 - loss: 0.0294 - val_accuracy: 0.9453 - val_loss: 0.0250 - learning_rate: 1.0000e-06
# Epoch 88/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.9359 - loss: 0.0261 - val_accuracy: 0.9448 - val_loss: 0.0248 - learning_rate: 1.0000e-06
# Epoch 89/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 178ms/step - accuracy: 0.9062 - loss: 0.0255 - val_accuracy: 0.9448 - val_loss: 0.0248 - learning_rate: 1.0000e-06
# Epoch 90/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - accuracy: 0.9388 - loss: 0.0260 - val_accuracy: 0.9464 - val_loss: 0.0249 - learning_rate: 1.0000e-06
# Epoch 91/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 0.9375 - loss: 0.0230 - val_accuracy: 0.9470 - val_loss: 0.0249 - learning_rate: 1.0000e-06
# Epoch 92/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 278s 1s/step - accuracy: 0.9326 - loss: 0.0262 - val_accuracy: 0.9448 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 93/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 1.0000 - loss: 0.0236 - val_accuracy: 0.9448 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 94/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.9408 - loss: 0.0257 - val_accuracy: 0.9470 - val_loss: 0.0249 - learning_rate: 1.0000e-06
# Epoch 95/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 0.9062 - loss: 0.0279 - val_accuracy: 0.9470 - val_loss: 0.0249 - learning_rate: 1.0000e-06
# Epoch 96/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.9387 - loss: 0.0259 - val_accuracy: 0.9448 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 97/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 0.9375 - loss: 0.0250 - val_accuracy: 0.9448 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 98/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.9383 - loss: 0.0259 - val_accuracy: 0.9442 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Epoch 99/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.9688 - loss: 0.0273 - val_accuracy: 0.9442 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Epoch 100/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.9357 - loss: 0.0257 - val_accuracy: 0.9442 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 99.
# Training Completed (Fine-Tuning).

# %% [markdown]
# ## 7.2 Enhanced History Visualization
# Plotting curves with markings for the Best Epoch (Lowest Validation Loss).

# %%
# Plot History with Best Epoch Marker
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

# Find Best Epoch
best_epoch = np.argmin(val_loss)
best_loss = val_loss[best_epoch]
best_acc = val_acc[best_epoch]

plt.figure(figsize=(14, 5))
plt.suptitle(f"Training Metrics (Best Epoch: {best_epoch+1})", fontsize=16)

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.scatter([best_epoch], [best_acc], color='green', marker='o', s=100, label=f'Best Val Acc: {best_acc:.2f}')
plt.plot([9, 9], plt.ylim(), label='Fine-Tuning Start', linestyle='--', color='purple')
plt.legend(loc='lower right')
plt.title('Accuracy')

# Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.scatter([best_epoch], [best_loss], color='red', marker='x', s=100, label=f'Best Val Loss: {best_loss:.2f}')
plt.axvline(best_epoch, color='gray', linestyle='--', alpha=0.5)
plt.plot([9, 9], plt.ylim(), label='Fine-Tuning Start', linestyle='--', color='purple')
plt.legend(loc='upper right')
plt.title('Loss')

plt.show()

# %% [markdown]
# # Part 8: Model Evaluation & Interpretation

# %%
print("Evaluating on Test Set...")
test_loss, test_acc = model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_acc:.4f}")

# Classification Report
test_generator.reset()
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# Confusion Matrix Heatmap
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix (Heatmap)')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.show()
# Out:
# Evaluating on Test Set...
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 47s 830ms/step - accuracy: 0.9539 - loss: 0.0245
#
# Test Accuracy: 0.9539
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 49s 833ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       drowsy       0.96      0.94      0.95       900
#   non-drowsy       0.95      0.96      0.95       900
#
#     accuracy                           0.95      1800
#    macro avg       0.95      0.95      0.95      1800
# weighted avg       0.95      0.95      0.95      1800

# %%
# ROC Curve Plot
fpr, tpr, thresholds = roc_curve(true_classes, predictions[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
print("Visualizing Misclassified Images (Sample Images)...")
errors = np.where(predicted_classes != true_classes)[0]

if len(errors) == 0:
    print("Amazing! No errors found on Test Set.")
else:
    # Show top 10 errors
    num_errors = min(10, len(errors))
    plt.figure(figsize=(20, 4))
    
    for i, error_idx in enumerate(errors[:num_errors]):
        img_path = test_generator.filepaths[error_idx]
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        true_label = class_labels[true_classes[error_idx]]
        pred_label = class_labels[predicted_classes[error_idx]]
        # Handle filename info safely
        if "Black" in img_path: origin = "BW"
        else: origin = "Color"
        
        plt.subplot(1, num_errors, i+1)
        # Use preprocess inverse for display
        plt.imshow(img, cmap='gray' if origin=='BW' else None)
        plt.axis('off')
        plt.title(f"True: {true_label}\nPred: {pred_label}", fontsize=8, color='red')
    plt.suptitle("Failure Analysis Examples", fontsize=14)
    plt.show()
# Out:
# Visualizing Misclassified Images (Sample Images)...

# %% [markdown]
# # Part 9: Saving Models

# %%
MODELS_DIR = BASE_DIR.parent / "Models"
MODELS_DIR.mkdir(parents=True, exist_ok=True)

# 1. Save Keras Model (.h5)
h5_path = MODELS_DIR / "drowsiness_model_resnet.h5"
model.save(str(h5_path))
print(f"✅ Keras model saved to: {h5_path}")

# 2. Convert to TensorFlow Lite (.tflite)
print("Converting to TFLite...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

tflite_path = MODELS_DIR / "resnet_quantized.tflite"
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)
print(f"✅ TFLite model saved to: {tflite_path}")

# 3. Save History (.pickle)
history_path = MODELS_DIR / "training_history_resnet.pickle"
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f)
print(f"✅ History saved to: {history_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Keras model saved to: c:\Users\SAHAN\Desktop\CNN\Models\drowsiness_model_resnet.h5
# Converting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\SAHAN\AppData\Local\Temp\tmpv2oozkzy\assets
# INFO:tensorflow:Assets written to: C:\Users\SAHAN\AppData\Local\Temp\tmpv2oozkzy\assets
# Saved artifact at 'C:\Users\SAHAN\AppData\Local\Temp\tmpv2oozkzy'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   2877513757520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877513750224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877517998864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518002704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877490461200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877517999056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877517995024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877512688912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877513296656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518207824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877517994832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877512690256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518209744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518211280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518210896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518206096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518207632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518211088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518215504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518211472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877517796880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877513438352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518002896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877517995216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877517797264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877517797072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518457808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518446672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518458576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518458000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518449168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518447248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518458192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518458384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518448976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518457424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518453008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518459152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518453584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518453392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518457232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518454928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518459344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518460304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518459728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518459536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518453200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518459920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518460688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518461648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518461072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518460880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518460496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518461264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518462032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518461840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518462416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518462224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518462800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518462608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877518461456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519414480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519414096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519413904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519413328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519414288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519415824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519416784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519416400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519416208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519413712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519416592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519416976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519417936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519417552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519417360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519414864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519417744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519418128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519419088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519414672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519415632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519415248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519415056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519413520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519415440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519418704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519418512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519416016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519418896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519419472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519420432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519420048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519419856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519419280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519420240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519420816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519421776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519421392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519421200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519420624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519421584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519421968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519422544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519422352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519417168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519422736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519423120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519424080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519423696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519423504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519421008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519423888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519424272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519424848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519424656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519422160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519425424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519426000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519425808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519423312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519426192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519426576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519427536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519427152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519426960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519424464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519427344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519427728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519428688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519428304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519428112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519425616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519428496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519428880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519429072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519426768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877519429264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532751440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532752400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532751824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532749904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532752208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532752592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532753552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532753168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532752976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532750480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532753360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532753744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532754704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532750288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532751248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532750864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532750672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532750096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532751056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532754320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532754128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532751632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532754512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532754896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532755856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532755472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532755280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532752784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532755664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532756048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532757008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532756624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532756432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532753936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532756816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532757200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532758160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532757776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532757584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532755088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532757968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532758352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532759312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532758736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532756240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532759120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532760464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532760080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532759888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532757392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532760272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532760656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532761616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532761040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532758544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532761424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532761808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532762768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532762384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532762192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532759696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532762576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532762960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532763920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532763536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532763344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532763728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532764112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532765072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532764688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532764496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532762000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532764880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532765264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532764304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532765648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532765456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532766032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532765840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877532763152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611885776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611885392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611885200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611884624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611885584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611885968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611886928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611886544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611886352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611884816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611886736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611887120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611888080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611887696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611887504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611887888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611888272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611888848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611888656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611886160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611889040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611889424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611890384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611890000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611889808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611887312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611890192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611891728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611892688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611892304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611892112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611889616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611892496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611892880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611893840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611893456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611893264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611890768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611893648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611894032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611894992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611890576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611891536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611891152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611890960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611888464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611891344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611894608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611894416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611891920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611894800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611895184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611896144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611895760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611895568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611893072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611895952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611896336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611897296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611896912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611896720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611894224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611897104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611897488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611898448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611898064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611897872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611895376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611898256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611898640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611899600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611899216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611899024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611896528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611899408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611899792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611900752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611900368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611900176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611897680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611900560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611899984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877611898832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877616128656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877616128464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877616128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877616128848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877616130000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877616130960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877616130576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2877616131536: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ TFLite model saved to: c:\Users\SAHAN\Desktop\CNN\Models\resnet_quantized.tflite
# ✅ History saved to: c:\Users\SAHAN\Desktop\CNN\Models\training_history_resnet.pickle
