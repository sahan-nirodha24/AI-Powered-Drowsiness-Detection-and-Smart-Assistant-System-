# %% [markdown]
# # 🚗 Driver Drowsiness Detection System (Multi-Class 4-State)
# ## Model Architecture: ResNet50 (Transfer Learning)
#
# This notebook implements a deep learning solution for detecting driver drowsiness using computer vision. The system is trained on an expanded dataset of **12,000 images** and utilizes **ResNet50** via transfer learning to achieve high accuracy and robustness.
#
# ### ✨ Key Upgrades & Features:
# - **Multi-Class Transition**: Successfully expanded from binary classification to a robust 4-class system (Distracted, Drowsy, Non-Drowsy, Yawn).
# - **Data Scaling & Augmentation**: Dynamic brightness and spatial augmentations to handle varying lighting conditions inside a vehicle.
# - **Hard Negative Mining**: Integration of **Categorical Focal Crossentropy loss** to significantly reduce False Positives and False Negatives.
# - **Advanced Fine-Tuning**: Strategic unfreezing of deep layers coupled with L2 Regularization and Learning Rate Schedulers.
#
# ---
# ### 📋 Complete Analysis Workflow Index
#
# #### Part 1: Dataset Understanding (Basic Check)
# 1. **Structure & Distribution**: Counting images per class/split.
# 2. **Resolution & Color**: Verifying dimensions and channel counts.
#
# #### Part 2: Detailed EDA
# 3. **Visual EDA**: Inspecting samples, face visibility, and variations.
# 4. **Statistical EDA**: Pixel distributions, brightness, and blur detection.
#
# #### Part 3: Feature Encoding
# 5. **Label Encoding**: Converting text labels to Multi-Class One-Hot vectors (4 Classes).
#
# #### Part 4: Data Preprocessing
# 6. **Resizing & Normalization**: Standardizing to 224x224 and scaling pixel values.
# 7. **Data Augmentation**: Enhancing dataset variety.
#
# #### Part 5: Dataset Splitting & Loading
# 8. **Generators**: Loading Train/Val/Test splits (70/15/15 ratio).
#
# #### Part 6: Model Building & Architecture
# 9. **Model Preparation**: Building ResNet50 base with custom classification head.
#
# #### Part 7: Model Training
# 10. **Phase 1 Training**: Training Classification Head.
# 11. **Phase 2 Fine-Tuning**: Deep layer unfreezing and training with low LR.
#
# #### Part 8: Model Evaluation & Interpretation
# 12. **Evaluation Metrics**: Precision, Recall, F1, Accuracy.
# 13. **Confusion Matrix**: Visualizing misclassifications and analyzing Failed Cases.
#
# #### Part 9: Exporting
# 14. **Keras & TFLite**: Saving models for production and edge deployment (Raspberry Pi/Mobile).
#
#
# > *This section focuses on analyzing the underlying directory structure and ensuring the raw images for all 4 classes are loaded correctly.*

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import pandas as pd
import pickle
import tensorflow as tf
from collections import Counter
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, Flatten, Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Output Style
plt.style.use('ggplot')

# Define paths
BASE_DIR = Path(r"C:\Users\SAHAN\Desktop\My Part Mid Demo 02\CNN\Processed_Dataset")
TRAIN_DIR = BASE_DIR / "train"
VAL_DIR = BASE_DIR / "val"
TEST_DIR = BASE_DIR / "test"

CATEGORIES = ["distracted", "drowsy", "non-drowsy", "yawn"]
TARGET_SIZE = (224, 224)
BATCH_SIZE = 32

# %% [markdown]
# # Part 1: Dataset Understanding
#
# > *This section focuses on analyzing the underlying directory structure and ensuring the raw images for all 4 classes are loaded correctly.*

# %%
stats = []

for split in ["train", "val", "test"]:
    for category in CATEGORIES:
        folder = BASE_DIR / split / category
        count = len(list(folder.glob("*")))
        stats.append({
            "Split": split,
            "Category": category,
            "Count": count
        })

df_stats = pd.DataFrame(stats)
print("Dataset Statistics:")
print(df_stats)

# Visualize
df_stats.pivot(index="Split", columns="Category", values="Count").plot(kind="bar", stacked=True, figsize=(10, 6))
plt.title("Image Distribution per Split")
plt.ylabel("Number of Images")
plt.show()
# Out:
# Dataset Statistics:
#     Split    Category  Count
# 0   train  distracted   2100
# 1   train      drowsy   2100
# 2   train  non-drowsy   2100
# 3   train        yawn   2100
# 4     val  distracted    450
# 5     val      drowsy    450
# 6     val  non-drowsy    450
# 7     val        yawn    450
# 8    test  distracted    450
# 9    test      drowsy    450
# 10   test  non-drowsy    450
# 11   test        yawn    450

# %% [markdown]
# ## 1.2 Image Resolution and Color Space Analysis

# %%
# Sample analysis (iterating through training set)
resolutions = []
channels = []
print("Scanning the entire dataset for property check...")

sample_count = 0
for category in CATEGORIES:
    folder = TRAIN_DIR / category
    for img_path in folder.glob("*"):
        # if sample_count >= 12000: break
        img = cv2.imread(str(img_path))
        if img is not None:
            resolutions.append(img.shape[:2])
            channels.append(img.shape[2] if len(img.shape) > 2 else 1)
            sample_count += 1

print(f"Resolution Check: {Counter([str(r) for r in resolutions])}")
print(f"Channel Check (OpenCV loads): {Counter(channels)}")
# Out:
# Scanning the entire dataset for property check...
# Resolution Check: Counter({'(224, 224)': 8400})
# Channel Check (OpenCV loads): Counter({3: 8400})

# %% [markdown]
# # Part 2: Detailed Exploratory Data Analysis (EDA)
#
# > *Here, we visualize sample images and compute statistical metrics (like brightness distribution) to understand the visual differences between driver states.*

# %%
def clean_filename_info(filename):
    has_glasses = "with_glasses" in filename
    origin = "BW" if "Black&White" in filename else "Color"
    return origin, has_glasses

def view_grid(category, samples=5):
    folder = TRAIN_DIR / category
    all_files = list(folder.glob("*"))
    selected = np.random.choice(all_files, samples, replace=False)
    
    plt.figure(figsize=(15, 4))
    plt.suptitle(f"Class: {category.upper()}", fontsize=14)
    
    for i, path in enumerate(selected):
        img = cv2.imread(str(path))
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        origin, glasses = clean_filename_info(path.name)
        plt.subplot(1, samples, i+1)
        plt.imshow(img, cmap='gray' if origin=='BW' else None)
        plt.axis('off')
        plt.title(f"{origin} | {'Glasses' if glasses else 'No Glass'}", fontsize=10)
    plt.show()



for category in CATEGORIES:
    view_grid(category, 3)

# %% [markdown]
# ## 2.1 Statistical Plot: Brightness Distribution
# Checking if there is a significant lighting difference between the different driver state classes.

# %%
brightness_values = {cat: [] for cat in CATEGORIES}

print("Calculating brightness stats for the entire dataset...")
for category in CATEGORIES:
    folder = TRAIN_DIR / category
    for i, img_path in enumerate(folder.glob("*")):
        # if i >= 12000: break
        img = cv2.imread(str(img_path))
        if img is not None:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            brightness_values[category].append(np.mean(gray))

plt.figure(figsize=(10, 5))
colors = ['red', 'blue', 'green', 'orange']
for cat, color in zip(CATEGORIES, colors):
    sns.kdeplot(brightness_values[cat], fill=True, label=cat.title(), color=color)
plt.title("Brightness Distribution Analysis")
plt.xlabel("Average Pixel Intensity (Brightness)")
plt.legend()
plt.show()
# Out:
# Calculating brightness stats for the entire dataset...

# %%
# Gather Metadata
data = []
for category in CATEGORIES:
    folder = TRAIN_DIR / category
    for filepath in folder.glob("*"):
        origin, has_glasses = clean_filename_info(filepath.name)
        data.append({"category": category, "has_glasses": has_glasses})

df = pd.DataFrame(data)
summary = df.groupby(["category", "has_glasses"]).size().reset_index(name="count")
print("Sub-category Distribution in Train Set:")
print(summary)
# Out:
# Sub-category Distribution in Train Set:
#      category  has_glasses  count
# 0  distracted        False   1036
# 1  distracted         True   1064
# 2      drowsy        False   1043
# 3      drowsy         True   1057
# 4  non-drowsy        False   1047
# 5  non-drowsy         True   1053
# 6        yawn        False   1034
# 7        yawn         True   1066

# %% [markdown]
# # Part 3: Feature Encoding (Enhanced)
#
# > *This step involves converting our categorical text labels (`distracted`, `drowsy`, `non-drowsy`, `yawn`) into numerical One-Hot vectors that the neural network can mathematically process.*

# %%
labels = CATEGORIES
label_map = {label: i for i, label in enumerate(labels)}
print(f"Class Mapping: {label_map}")

# 1. Visualizing One-Hot Vectors Table
demo_encoding = pd.DataFrame({
    'Class': CATEGORIES,
    'Label Index': list(range(len(CATEGORIES))),
    'One-Hot': [str(to_categorical(i, len(CATEGORIES))) for i in range(len(CATEGORIES))]
})
print("\nEncoding Reference Table:")
print(demo_encoding)

# 2. Visualizing Class Balance using Encoded Labels
train_counts = [len(list((TRAIN_DIR / cat).glob("*"))) for cat in CATEGORIES]

plt.figure(figsize=(8, 4))
plt.bar([f'Label {i} ({cat.title()})' for i, cat in enumerate(CATEGORIES)], 
        train_counts, 
        color=['salmon', 'skyblue', 'lightgreen', 'gold'])
plt.title("Class Balance by Encoded Label (Training Set)")
plt.ylabel("Count")
plt.show()
# Out:
# Class Mapping: {'distracted': 0, 'drowsy': 1, 'non-drowsy': 2, 'yawn': 3}
#
# Encoding Reference Table:
#         Class  Label Index        One-Hot
# 0  distracted            0  [1. 0. 0. 0.]
# 1      drowsy            1  [0. 1. 0. 0.]
# 2  non-drowsy            2  [0. 0. 1. 0.]
# 3        yawn            3  [0. 0. 0. 1.]

# %%
# 3. Sample Images with Vector Labels
plt.figure(figsize=(16, 4))
plt.suptitle("Data as Seen by Model: Image + One-Hot Vector", fontsize=14)

for i, category in enumerate(CATEGORIES):
    folder = TRAIN_DIR / category
    img_path = list(folder.glob("*"))[0]
    img = cv2.imread(str(img_path))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    encoded_label = to_categorical(label_map[category], num_classes=len(CATEGORIES))
    
    plt.subplot(1, len(CATEGORIES), i+1)
    plt.imshow(img, cmap='gray' if "Black" in str(img_path) else None)
    plt.title(f"Class: {category}\nVector: {encoded_label}")
    plt.axis('off')
plt.show()

# %% [markdown]
# # Part 4: Data Preprocessing & Visualization
#
# > *In this section, raw images are mathematically scaled (normalized) and augmented (rotated, zoomed) to make the model robust against different driving and lighting conditions.*

# %%
# Setup Generators with ResNet50 Preprocessing (Correct for Transfer Learning)
from tensorflow.keras.applications.resnet50 import preprocess_input

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input, # Scales to [-1, 1]
    rotation_range=20,       # Rotation
    width_shift_range=0.2,   # Horizontal Shift
    height_shift_range=0.2,  # Vertical Shift
    zoom_range=0.2,          # Zoom
    brightness_range=[0.8, 1.2], # Added brightness range to handle lighting variations
    horizontal_flip=True,    # Flip
    fill_mode='nearest'      
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

print("Augmentation Configuration Set (ResNet50 [-1, 1]).")
# Out:
# Augmentation Configuration Set (ResNet50 [-1, 1]).

# %% [markdown]
# ## 4.1 Visualize Augmentation Effects
# Checking how "Rotation", "Zoom", and "Shift" actually affect our images.

# %%
def visualize_augmentation(category):
    # Pick a random image
    folder = TRAIN_DIR / category
    img_path = list(folder.glob("*"))[0]
    img = load_img(str(img_path), target_size=TARGET_SIZE)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    plt.figure(figsize=(15, 6))
    plt.suptitle(f"Augmentation Random Samples: {category.upper()}", fontsize=16)

    # Plot Original
    plt.subplot(2, 4, 1)
    plt.imshow(img)
    plt.title("Original")
    plt.axis('off')

    # Plot Augmented Versions
    for batch in train_datagen.flow(x, batch_size=1):
        plt.subplot(2, 4, i + 2)
        img_aug = batch[0] 
        # Rescale back to 0-1 for visualization if needed (resnet is -1 to 1)
        img_viz = img_aug - np.min(img_aug)
        img_viz = img_viz / (np.max(img_viz) + 1e-5)
        plt.imshow(img_viz)
        plt.title(f"Augment {i+1}")
        plt.axis('off')
        i += 1
        if i >= 7: break
    plt.show()

visualize_augmentation(CATEGORIES[0])

# %% [markdown]
# ## 4.2 Using ResNet50 Preprocessing
# Note: The values have been mean-centered with respect to the ImageNet dataset using BGR format, which is the specific standard constraint required for ResNet50.

# %%
# Preprocessing Analysis
sample_path = list((TRAIN_DIR / CATEGORIES[0]).glob("*"))[0]
original_img = cv2.imread(str(sample_path))
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

# Apply Preprocessing manually
preprocessed_img = cv2.resize(original_img, TARGET_SIZE)
preprocessed_img = preprocessed_img.astype("float32")
preprocessed_img = preprocess_input(preprocessed_img) # [-1, 1]

plt.figure(figsize=(12, 5))

# 1. Pixel Value Histogram (Normalization Check)
plt.subplot(1, 2, 1)
sns.histplot(original_img.flatten(), color='red', label='Original (0-255)', kde=True, stat="density", alpha=0.3)
sns.histplot(preprocessed_img.flatten(), color='blue', label='Preprocessed (-1 to 1)', kde=True, stat="density", alpha=0.3)
plt.title("Pixel Intensity Distribution Check")
plt.legend()

# 2. Input Tensor Heatmap (What the CNN 'sees' in shape)
plt.subplot(1, 2, 2)
heatmap_img = np.mean(preprocessed_img, axis=2)
sns.heatmap(heatmap_img, cmap="viridis", cbar=True)
plt.title("Input Tensor Heatmap (Mean Channel)")
plt.axis('off')

plt.show()

# %% [markdown]
# # Part 5: Dataset Splitting & Loading (Enhanced)
#
# > *The dataset is divided into Training, Validation, and Testing sets using data generators to feed images in batches during training without overloading RAM.*

# %%
print("Loading Data from Directory Structure...")

# 1. Load Training Set
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# 2. Load Validation Set
validation_generator = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False 
)

# 3. Load Test Set
test_generator = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"\nClass Indices: {train_generator.class_indices}")
# Out:
# Loading Data from Directory Structure...
# Found 8400 images belonging to 4 classes.
# Found 1800 images belonging to 4 classes.
# Found 1800 images belonging to 4 classes.
#
# Class Indices: {'distracted': 0, 'drowsy': 1, 'non-drowsy': 2, 'yawn': 3}

# %% [markdown]
# ## 5.1 Visualize Generator Output (Batch Verification)

# %%
# Fetch a batch
x_batch, y_batch = next(train_generator)

# Visualize 8 random images from the batch
plt.figure(figsize=(15, 8))
plt.suptitle("Generator Batch Visualization (Correct Labels?)", fontsize=16)

class_names = list(train_generator.class_indices.keys())

for i in range(8):
    plt.subplot(2, 4, i+1)
    # Convert back to 0-1 for display
    img_disp = x_batch[i] - np.min(x_batch[i])
    img_disp = img_disp / (np.max(img_disp) + 1e-5)
    plt.imshow(img_disp)
    
    # Decode One-Hot Label
    label_idx = np.argmax(y_batch[i])
    label_name = class_names[label_idx]
    
    plt.title(f"Label: {label_name}\n{y_batch[i]}")
    plt.axis('off')
plt.show()

# %% [markdown]
# ## 5.2 Split Distribution Visualization

# %%
counts = [train_generator.samples, validation_generator.samples, test_generator.samples]
labels = [f'Train ({counts[0]})', f'Val ({counts[1]})', f'Test ({counts[2]})']
colors = ['#ff9999', '#66b3ff', '#99ff99']

plt.figure(figsize=(7, 7))
plt.pie(counts, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, explode=(0.05, 0, 0))
plt.title("Final Dataset Split Distribution")
plt.show()

# %% [markdown]
# # Part 6: Model Architecture & Transfer Learning Setup
#
# > *We initialize a pre-trained base model and attach a custom Multi-Class classification head (Dense Layer) optimized specifically for our 4 driver states.*

# %%
from tensorflow.keras.regularizers import l2
def build_resnet_model(input_shape=(224, 224, 3), num_classes=4):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x) 
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

model = build_resnet_model()
INIT_LR = 1e-4
opt = Adam(learning_rate=INIT_LR)
model.compile(loss=CategoricalFocalCrossentropy(), optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ## 6.1 Visualize Model Complexity
# Visualizing the parameters per layer to understand the model structure.

# %%
# Visualizing Transfer Learning Layers
layer_names = []
layer_params = []

for layer in model.layers:
    layer_names.append(layer.name)
    layer_params.append(layer.count_params())

# Show only top 10 heaviest layers + last 3 custom layers
indices = np.argsort(layer_params)[-10:]
sorted_names = [layer_names[i] for i in indices]
sorted_params = [layer_params[i] for i in indices]

# Add Custom Head
custom_names = [l.name for l in model.layers[-3:]]
custom_params = [l.count_params() for l in model.layers[-3:]]

plt.figure(figsize=(12, 6))
plt.barh(sorted_names + custom_names, sorted_params + custom_params, color='purple')
plt.xlabel("Number of Parameters")
plt.title("Model Complexity: Top Layers + Custom Head")
plt.grid(axis='x')
plt.show()

print(f"Total Parameters: {model.count_params():,}")
print(f"Trainable Parameters: {np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Total Parameters: 23,850,500
# Trainable Parameters: 262,788

# %% [markdown]
# # Part 7: Hard Negative Mining & Model Training (With Fine-Tuning)
#
# > *The model is trained in phases—first training the custom head, and then carefully fine-tuning the deeper layers alongside class weights to maximize accuracy across all classes.*

# %%
# --- TRAINING PHASE 1: Train Head Only ---
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=12,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2,
    patience=3, 
    min_lr=1e-6,
    verbose=1
)

from sklearn.utils import class_weight
# --- TRAINING PHASE 1: Train Head Only ---
print("Starting Training Phase 1 (Head Only)...")
# NEW: Compute class weights to handle dataset imbalance
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights_dict = dict(enumerate(class_weights))
print(f"Computed Class Weights: {class_weights_dict}")
history_1 = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    epochs=10, # Initial training
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights_dict # <--- NEW: Pass calculated weights to the model
)

# --- TRAINING PHASE 2: Fine-Tuning ---
print("\nStarting Training Phase 2 (Fine-Tuning)...")
# 1. Unfreeze the base model
model.trainable = True
# 2. Freeze earlier layers 
# NEW: Increased frozen layers from 100 to 120 to reduce overfitting during fine-tuning
FINE_TUNE_AT = 140
for layer in model.layers[:FINE_TUNE_AT]:
    layer.trainable = False
print(f"Layers frozen: {FINE_TUNE_AT}. Layers trainable: {len(model.layers) - FINE_TUNE_AT}")
# 3. Re-compile with label smoothing and very low learning rate
model.compile(
    loss=CategoricalFocalCrossentropy(), # <--- NEW: Re-applied label smoothing
    optimizer=Adam(learning_rate=1e-5), 
    metrics=["accuracy"]
)
# 4. Continue Training
total_epochs = 100 # 30 + 20
history_fine = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    initial_epoch=history_1.epoch[-1],
    epochs=total_epochs,
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights_dict # <--- NEW: Pass class weights to fine-tuning phase as well
)
print("Training Completed (Fine-Tuning).")

# Merge Histories for Plotting
acc = history_1.history['accuracy'] + history_fine.history['accuracy']
val_acc = history_1.history['val_accuracy'] + history_fine.history['val_accuracy']
loss = history_1.history['loss'] + history_fine.history['loss']
val_loss = history_1.history['val_loss'] + history_fine.history['val_loss']

# Create a dummy history object wrapper for compatibility with downstream plotting code
class CombinedHistory:
    def __init__(self):
        self.history = {
            'accuracy': acc,
            'val_accuracy': val_acc,
            'loss': loss,
            'val_loss': val_loss
        }
history = CombinedHistory()
# Out:
# Starting Training Phase 1 (Head Only)...
# Computed Class Weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0)}
# C:\Users\SAHAN\AppData\Roaming\Python\Python313\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 990ms/step - accuracy: 0.6239 - loss: 1.9656 - val_accuracy: 0.8298 - val_loss: 1.3730 - learning_rate: 1.0000e-04
# Epoch 2/10
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 3:33 819ms/step - accuracy: 0.6562 - loss: 1.4099
# C:\Users\SAHAN\AppData\Roaming\Python\Python313\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 48s 180ms/step - accuracy: 0.6562 - loss: 1.4099 - val_accuracy: 0.8298 - val_loss: 1.3697 - learning_rate: 1.0000e-04
# Epoch 3/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.7815 - loss: 1.0332 - val_accuracy: 0.8438 - val_loss: 0.7354 - learning_rate: 1.0000e-04
# Epoch 4/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 172ms/step - accuracy: 0.8438 - loss: 0.7587 - val_accuracy: 0.8426 - val_loss: 0.7332 - learning_rate: 1.0000e-04
# Epoch 5/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 260s 994ms/step - accuracy: 0.8130 - loss: 0.5697 - val_accuracy: 0.8711 - val_loss: 0.4146 - learning_rate: 1.0000e-04
# Epoch 6/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 173ms/step - accuracy: 0.6875 - loss: 0.4517 - val_accuracy: 0.8683 - val_loss: 0.4142 - learning_rate: 1.0000e-04
# Epoch 7/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.8363 - loss: 0.3389 - val_accuracy: 0.8945 - val_loss: 0.2536 - learning_rate: 1.0000e-04
# Epoch 8/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 75s 282ms/step - accuracy: 0.8438 - loss: 0.2695 - val_accuracy: 0.8929 - val_loss: 0.2532 - learning_rate: 1.0000e-04
# Epoch 9/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 450s 2s/step - accuracy: 0.8524 - loss: 0.2203 - val_accuracy: 0.8962 - val_loss: 0.1687 - learning_rate: 1.0000e-04
# Epoch 10/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 75s 283ms/step - accuracy: 0.8750 - loss: 0.1828 - val_accuracy: 0.8990 - val_loss: 0.1684 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 10.
#
# Starting Training Phase 2 (Fine-Tuning)...
# Layers frozen: 140. Layers trainable: 39
# Epoch 10/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 484s 2s/step - accuracy: 0.8733 - loss: 0.1722 - val_accuracy: 0.9096 - val_loss: 0.1583 - learning_rate: 1.0000e-05
# Epoch 11/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 78s 293ms/step - accuracy: 0.9375 - loss: 0.1644 - val_accuracy: 0.9090 - val_loss: 0.1582 - learning_rate: 1.0000e-05
# Epoch 12/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 387s 1s/step - accuracy: 0.8804 - loss: 0.1634 - val_accuracy: 0.9146 - val_loss: 0.1506 - learning_rate: 1.0000e-05
# Epoch 13/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 175ms/step - accuracy: 0.8750 - loss: 0.1643 - val_accuracy: 0.9152 - val_loss: 0.1507 - learning_rate: 1.0000e-05
# Epoch 14/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.8769 - loss: 0.1567 - val_accuracy: 0.9051 - val_loss: 0.1439 - learning_rate: 1.0000e-05
# Epoch 15/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9062 - loss: 0.1501 - val_accuracy: 0.9057 - val_loss: 0.1439 - learning_rate: 1.0000e-05
# Epoch 16/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.8864 - loss: 0.1487 - val_accuracy: 0.9051 - val_loss: 0.1375 - learning_rate: 1.0000e-05
# Epoch 17/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 49s 186ms/step - accuracy: 0.8750 - loss: 0.1517 - val_accuracy: 0.9051 - val_loss: 0.1375 - learning_rate: 1.0000e-05
# Epoch 18/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.8844 - loss: 0.1426 - val_accuracy: 0.9219 - val_loss: 0.1312 - learning_rate: 1.0000e-05
# Epoch 19/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.8438 - loss: 0.1428 - val_accuracy: 0.9208 - val_loss: 0.1311 - learning_rate: 1.0000e-05
# Epoch 20/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.8902 - loss: 0.1366 - val_accuracy: 0.9252 - val_loss: 0.1255 - learning_rate: 1.0000e-05
# Epoch 21/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 175ms/step - accuracy: 0.9062 - loss: 0.1329 - val_accuracy: 0.9241 - val_loss: 0.1254 - learning_rate: 1.0000e-05
# Epoch 22/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.8905 - loss: 0.1314 - val_accuracy: 0.9185 - val_loss: 0.1208 - learning_rate: 1.0000e-05
# Epoch 23/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.8750 - loss: 0.1242 - val_accuracy: 0.9180 - val_loss: 0.1208 - learning_rate: 1.0000e-05
# Epoch 24/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.8883 - loss: 0.1272 - val_accuracy: 0.9247 - val_loss: 0.1160 - learning_rate: 1.0000e-05
# Epoch 25/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 175ms/step - accuracy: 0.9375 - loss: 0.1204 - val_accuracy: 0.9247 - val_loss: 0.1160 - learning_rate: 1.0000e-05
# Epoch 26/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.8907 - loss: 0.1217 - val_accuracy: 0.9224 - val_loss: 0.1117 - learning_rate: 1.0000e-05
# Epoch 27/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9688 - loss: 0.1108 - val_accuracy: 0.9235 - val_loss: 0.1117 - learning_rate: 1.0000e-05
# Epoch 28/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.8946 - loss: 0.1172 - val_accuracy: 0.9213 - val_loss: 0.1081 - learning_rate: 1.0000e-05
# Epoch 29/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 175ms/step - accuracy: 0.9688 - loss: 0.1056 - val_accuracy: 0.9213 - val_loss: 0.1082 - learning_rate: 1.0000e-05
# Epoch 30/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.8926 - loss: 0.1138 - val_accuracy: 0.9208 - val_loss: 0.1041 - learning_rate: 1.0000e-05
# Epoch 31/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 173ms/step - accuracy: 1.0000 - loss: 0.0962 - val_accuracy: 0.9196 - val_loss: 0.1041 - learning_rate: 1.0000e-05
# Epoch 32/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.8996 - loss: 0.1090 - val_accuracy: 0.9185 - val_loss: 0.1004 - learning_rate: 1.0000e-05
# Epoch 33/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.7812 - loss: 0.1069 - val_accuracy: 0.9185 - val_loss: 0.1004 - learning_rate: 1.0000e-05
# Epoch 34/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.8959 - loss: 0.1064 - val_accuracy: 0.9275 - val_loss: 0.0968 - learning_rate: 1.0000e-05
# Epoch 35/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9062 - loss: 0.1028 - val_accuracy: 0.9280 - val_loss: 0.0968 - learning_rate: 1.0000e-05
# Epoch 36/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.8958 - loss: 0.1033 - val_accuracy: 0.9185 - val_loss: 0.0950 - learning_rate: 1.0000e-05
# Epoch 37/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 173ms/step - accuracy: 0.8438 - loss: 0.1102 - val_accuracy: 0.9180 - val_loss: 0.0949 - learning_rate: 1.0000e-05
# Epoch 38/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.8978 - loss: 0.1002 - val_accuracy: 0.9286 - val_loss: 0.0909 - learning_rate: 1.0000e-05
# Epoch 39/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9062 - loss: 0.0964 - val_accuracy: 0.9286 - val_loss: 0.0909 - learning_rate: 1.0000e-05
# Epoch 40/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9055 - loss: 0.0960 - val_accuracy: 0.9275 - val_loss: 0.0883 - learning_rate: 1.0000e-05
# Epoch 41/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9375 - loss: 0.0867 - val_accuracy: 0.9252 - val_loss: 0.0882 - learning_rate: 1.0000e-05
# Epoch 42/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9056 - loss: 0.0937 - val_accuracy: 0.9342 - val_loss: 0.0852 - learning_rate: 1.0000e-05
# Epoch 43/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9688 - loss: 0.0819 - val_accuracy: 0.9353 - val_loss: 0.0852 - learning_rate: 1.0000e-05
# Epoch 44/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9068 - loss: 0.0911 - val_accuracy: 0.9258 - val_loss: 0.0833 - learning_rate: 1.0000e-05
# Epoch 45/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9688 - loss: 0.0806 - val_accuracy: 0.9263 - val_loss: 0.0832 - learning_rate: 1.0000e-05
# Epoch 46/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9052 - loss: 0.0886 - val_accuracy: 0.9325 - val_loss: 0.0803 - learning_rate: 1.0000e-05
# Epoch 47/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9062 - loss: 0.0837 - val_accuracy: 0.9336 - val_loss: 0.0803 - learning_rate: 1.0000e-05
# Epoch 48/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9094 - loss: 0.0859 - val_accuracy: 0.9325 - val_loss: 0.0782 - learning_rate: 1.0000e-05
# Epoch 49/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 173ms/step - accuracy: 0.8438 - loss: 0.0871 - val_accuracy: 0.9308 - val_loss: 0.0783 - learning_rate: 1.0000e-05
# Epoch 50/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.9107 - loss: 0.0844 - val_accuracy: 0.9358 - val_loss: 0.0763 - learning_rate: 1.0000e-05
# Epoch 51/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9062 - loss: 0.0753 - val_accuracy: 0.9381 - val_loss: 0.0762 - learning_rate: 1.0000e-05
# Epoch 52/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9082 - loss: 0.0821 - val_accuracy: 0.9314 - val_loss: 0.0739 - learning_rate: 1.0000e-05
# Epoch 53/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9375 - loss: 0.0747 - val_accuracy: 0.9314 - val_loss: 0.0739 - learning_rate: 1.0000e-05
# Epoch 54/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9128 - loss: 0.0796 - val_accuracy: 0.9364 - val_loss: 0.0720 - learning_rate: 1.0000e-05
# Epoch 55/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9062 - loss: 0.0819 - val_accuracy: 0.9364 - val_loss: 0.0720 - learning_rate: 1.0000e-05
# Epoch 56/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9112 - loss: 0.0780 - val_accuracy: 0.9375 - val_loss: 0.0703 - learning_rate: 1.0000e-05
# Epoch 57/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9062 - loss: 0.0812 - val_accuracy: 0.9353 - val_loss: 0.0703 - learning_rate: 1.0000e-05
# Epoch 58/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9109 - loss: 0.0762 - val_accuracy: 0.9381 - val_loss: 0.0681 - learning_rate: 1.0000e-05
# Epoch 59/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9688 - loss: 0.0702 - val_accuracy: 0.9381 - val_loss: 0.0680 - learning_rate: 1.0000e-05
# Epoch 60/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9137 - loss: 0.0737 - val_accuracy: 0.9308 - val_loss: 0.0672 - learning_rate: 1.0000e-05
# Epoch 61/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9375 - loss: 0.0758 - val_accuracy: 0.9302 - val_loss: 0.0671 - learning_rate: 1.0000e-05
# Epoch 62/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9128 - loss: 0.0727 - val_accuracy: 0.9325 - val_loss: 0.0658 - learning_rate: 1.0000e-05
# Epoch 63/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 175ms/step - accuracy: 0.9688 - loss: 0.0662 - val_accuracy: 0.9302 - val_loss: 0.0659 - learning_rate: 1.0000e-05
# Epoch 64/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9104 - loss: 0.0711 - val_accuracy: 0.9342 - val_loss: 0.0641 - learning_rate: 1.0000e-05
# Epoch 65/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9375 - loss: 0.0689 - val_accuracy: 0.9336 - val_loss: 0.0642 - learning_rate: 1.0000e-05
# Epoch 66/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9141 - loss: 0.0693 - val_accuracy: 0.9386 - val_loss: 0.0620 - learning_rate: 1.0000e-05
# Epoch 67/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 175ms/step - accuracy: 0.8125 - loss: 0.0814 - val_accuracy: 0.9375 - val_loss: 0.0621 - learning_rate: 1.0000e-05
# Epoch 68/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9189 - loss: 0.0671 - val_accuracy: 0.9414 - val_loss: 0.0605 - learning_rate: 1.0000e-05
# Epoch 69/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9375 - loss: 0.0685 - val_accuracy: 0.9414 - val_loss: 0.0604 - learning_rate: 1.0000e-05
# Epoch 70/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9112 - loss: 0.0667 - val_accuracy: 0.9358 - val_loss: 0.0599 - learning_rate: 1.0000e-05
# Epoch 71/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9688 - loss: 0.0619 - val_accuracy: 0.9353 - val_loss: 0.0600 - learning_rate: 1.0000e-05
# Epoch 72/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.9142 - loss: 0.0650 - val_accuracy: 0.9392 - val_loss: 0.0585 - learning_rate: 1.0000e-05
# Epoch 73/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9375 - loss: 0.0606 - val_accuracy: 0.9392 - val_loss: 0.0585 - learning_rate: 1.0000e-05
# Epoch 74/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9141 - loss: 0.0641 - val_accuracy: 0.9364 - val_loss: 0.0570 - learning_rate: 1.0000e-05
# Epoch 75/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.8125 - loss: 0.0743 - val_accuracy: 0.9369 - val_loss: 0.0571 - learning_rate: 1.0000e-05
# Epoch 76/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9152 - loss: 0.0630 - val_accuracy: 0.9392 - val_loss: 0.0560 - learning_rate: 1.0000e-05
# Epoch 77/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 173ms/step - accuracy: 0.8125 - loss: 0.0699 - val_accuracy: 0.9408 - val_loss: 0.0559 - learning_rate: 1.0000e-05
# Epoch 78/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9210 - loss: 0.0616 - val_accuracy: 0.9392 - val_loss: 0.0553 - learning_rate: 1.0000e-05
# Epoch 79/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 177ms/step - accuracy: 0.9688 - loss: 0.0556 - val_accuracy: 0.9397 - val_loss: 0.0553 - learning_rate: 1.0000e-05
# Epoch 80/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9177 - loss: 0.0602 - val_accuracy: 0.9386 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 81/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 1.0000 - loss: 0.0483 - val_accuracy: 0.9392 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 82/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9166 - loss: 0.0596 - val_accuracy: 0.9431 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 83/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.9375 - loss: 0.0588 - val_accuracy: 0.9420 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 84/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9196 - loss: 0.0586 - val_accuracy: 0.9386 - val_loss: 0.0519 - learning_rate: 1.0000e-05
# Epoch 85/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 47s 179ms/step - accuracy: 1.0000 - loss: 0.0450 - val_accuracy: 0.9381 - val_loss: 0.0519 - learning_rate: 1.0000e-05
# Epoch 86/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9201 - loss: 0.0575 - val_accuracy: 0.9442 - val_loss: 0.0507 - learning_rate: 1.0000e-05
# Epoch 87/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.8750 - loss: 0.0724 - val_accuracy: 0.9442 - val_loss: 0.0507 - learning_rate: 1.0000e-05
# Epoch 88/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9241 - loss: 0.0561 - val_accuracy: 0.9397 - val_loss: 0.0507 - learning_rate: 1.0000e-05
# Epoch 89/100
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 3:31 812ms/step - accuracy: 0.7812 - loss: 0.0656
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.7812 - loss: 0.0656 - val_accuracy: 0.9392 - val_loss: 0.0507 - learning_rate: 1.0000e-05
# Epoch 90/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9236 - loss: 0.0556 - val_accuracy: 0.9431 - val_loss: 0.0498 - learning_rate: 2.0000e-06
# Epoch 91/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9375 - loss: 0.0543 - val_accuracy: 0.9431 - val_loss: 0.0498 - learning_rate: 2.0000e-06
# Epoch 92/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9251 - loss: 0.0549 - val_accuracy: 0.9442 - val_loss: 0.0496 - learning_rate: 2.0000e-06
# Epoch 93/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9062 - loss: 0.0543 - val_accuracy: 0.9442 - val_loss: 0.0497 - learning_rate: 2.0000e-06
# Epoch 94/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.9290 - loss: 0.0544 - val_accuracy: 0.9442 - val_loss: 0.0491 - learning_rate: 2.0000e-06
# Epoch 95/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.8750 - loss: 0.0562 - val_accuracy: 0.9442 - val_loss: 0.0491 - learning_rate: 2.0000e-06
# Epoch 96/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.9238 - loss: 0.0544 - val_accuracy: 0.9431 - val_loss: 0.0489 - learning_rate: 2.0000e-06
# Epoch 97/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 174ms/step - accuracy: 0.9688 - loss: 0.0567 - val_accuracy: 0.9431 - val_loss: 0.0489 - learning_rate: 2.0000e-06
# Epoch 98/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9250 - loss: 0.0544 - val_accuracy: 0.9414 - val_loss: 0.0490 - learning_rate: 2.0000e-06
# Epoch 99/100
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 3:35 825ms/step - accuracy: 0.9688 - loss: 0.0465
# Epoch 99: ReduceLROnPlateau reducing learning rate to 1e-06.
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 46s 173ms/step - accuracy: 0.9688 - loss: 0.0465 - val_accuracy: 0.9414 - val_loss: 0.0490 - learning_rate: 2.0000e-06
# Epoch 100/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9229 - loss: 0.0548 - val_accuracy: 0.9431 - val_loss: 0.0488 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 100.
# Training Completed (Fine-Tuning).

# %% [markdown]
# ## 7.2 Enhanced History Visualization
# Plotting curves with markings for the Best Epoch (Lowest Validation Loss).

# %%
# Plot History with Best Epoch Marker
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

# Find Best Epoch
best_epoch = np.argmin(val_loss)
best_loss = val_loss[best_epoch]
best_acc = val_acc[best_epoch]

plt.figure(figsize=(14, 5))
plt.suptitle(f"Training Metrics (Best Epoch: {best_epoch+1})", fontsize=16)

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.scatter([best_epoch], [best_acc], color='green', marker='o', s=100, label=f'Best Val Acc: {best_acc:.2f}')
plt.plot([9, 9], plt.ylim(), label='Fine-Tuning Start', linestyle='--', color='purple')
plt.legend(loc='lower right')
plt.title('Accuracy')

# Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.scatter([best_epoch], [best_loss], color='red', marker='x', s=100, label=f'Best Val Loss: {best_loss:.2f}')
plt.axvline(best_epoch, color='gray', linestyle='--', alpha=0.5)
plt.plot([9, 9], plt.ylim(), label='Fine-Tuning Start', linestyle='--', color='purple')
plt.legend(loc='upper right')
plt.title('Loss')

plt.show()

# %% [markdown]
# # Part 8: Model Evaluation & Interpretation
#
# > *Using the unseen test set, we generate a Confusion Matrix and Multi-Class ROC Curves to critically analyze the model's performance on each specific class, followed by a detailed failure analysis.*

# %%
print("Evaluating on Test Set...")
test_loss, test_acc = model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_acc:.4f}")

# Classification Report
test_generator.reset()
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# Confusion Matrix Heatmap
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix (Heatmap)')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.show()
# Out:
# Evaluating on Test Set...
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 46s 810ms/step - accuracy: 0.9406 - loss: 0.0496
#
# Test Accuracy: 0.9406
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 47s 807ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   distracted       1.00      1.00      1.00       450
#       drowsy       0.93      0.89      0.91       450
#   non-drowsy       0.87      0.92      0.89       450
#         yawn       0.96      0.95      0.96       450
#
#     accuracy                           0.94      1800
#    macro avg       0.94      0.94      0.94      1800
# weighted avg       0.94      0.94      0.94      1800

# %%
# ROC Curve Plot (Multi-Class OvR)
from sklearn.preprocessing import label_binarize

# Binarize the output classes
n_classes = len(class_labels)
y_test_bin = label_binarize(true_classes, classes=list(range(n_classes)))

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], predictions[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 8))
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve of class {class_labels[i]} (area = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
print("Visualizing Misclassified Images (Sample Images)...")
errors = np.where(predicted_classes != true_classes)[0]

if len(errors) == 0:
    print("Amazing! No errors found on Test Set.")
else:
    # Show top 16 errors in a 4x4 grid
    num_errors = min(16, len(errors))
    import math
    cols = 4
    rows = math.ceil(num_errors / cols)
    
    plt.figure(figsize=(15, 3 * rows))
    
    for i, error_idx in enumerate(errors[:num_errors]):
        img_path = test_generator.filepaths[error_idx]
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        true_label = class_labels[true_classes[error_idx]]
        pred_label = class_labels[predicted_classes[error_idx]]
        # Handle filename info safely
        if "Black" in img_path: origin = "BW"
        else: origin = "Color"
        
        plt.subplot(rows, cols, i+1)
        # Use preprocess inverse for display
        plt.imshow(img, cmap='gray' if origin=='BW' else None)
        plt.axis('off')
        plt.title(f"True: {true_label}\nPred: {pred_label}", fontsize=10, color='red')
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.suptitle("Failure Analysis Examples", fontsize=16)
    plt.show()
# Out:
# Visualizing Misclassified Images (Sample Images)...

# %% [markdown]
# # Part 9: Saving Models
#
# > *The fully trained model is exported in `.h5` and `.tflite` formats, making it ready for real-time inference in external applications.*

# %%
MODELS_DIR = BASE_DIR.parent / "Models"
MODELS_DIR.mkdir(parents=True, exist_ok=True)

# 1. Save Keras Model (.h5)
h5_path = MODELS_DIR / "drowsiness_model_resnet.h5"
model.save(str(h5_path))
print(f"✅ Keras model saved to: {h5_path}")

# 2. Convert to TensorFlow Lite (.tflite)
print("Converting to TFLite...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

tflite_path = MODELS_DIR / "resnet_quantized.tflite"
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)
print(f"✅ TFLite model saved to: {tflite_path}")

# 3. Save History (.pickle)
history_path = MODELS_DIR / "training_history_resnet.pickle"
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f)
print(f"✅ History saved to: {history_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Keras model saved to: C:\Users\SAHAN\Desktop\My Part Mid Demo 02\CNN\Models\drowsiness_model_resnet.h5
# Converting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\SAHAN\AppData\Local\Temp\tmpwcur1yvr\assets
# INFO:tensorflow:Assets written to: C:\Users\SAHAN\AppData\Local\Temp\tmpwcur1yvr\assets
# Saved artifact at 'C:\Users\SAHAN\AppData\Local\Temp\tmpwcur1yvr'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2128986537616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129006979280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013758416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013767632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013758608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013767440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013972944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013977744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014190160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014190352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013973328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014189968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014192656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014188240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014189584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014192080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014188048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014185936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014180560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013973136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013977552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013977168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013975824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013966032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013977360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014182288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014193424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014185744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014180944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015144912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015145872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015145296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015145104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015144528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015145488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015146256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015147216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015146832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015146640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015145680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015147024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015147408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015148368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015147792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015147600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015146448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015147984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015148752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015149712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129009454416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014193232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015148560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015149328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013970256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014192464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014184976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014185168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014193040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014184784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129014192848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013757456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013767056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013766864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013753616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013757648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013571216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013558928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129009278608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129009278800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129009278224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129009278416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015149520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015150672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015150288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015150096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015149136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015150480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015150864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015151824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013767248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013753808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013559312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013571024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013562768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129013559120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015151440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015151248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015148944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015151632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015152208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015153168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015152784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015152592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015152016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015152976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015153552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015154512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015154128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015153936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015153360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015154320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015154704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015155664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015155280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015155088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015149904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015155472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015155856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015156816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015156432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015156240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015153744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015156624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015157008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015157968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015157584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015157392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015154896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015157776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015158160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015159120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015158736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015158544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015156048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015158928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015159312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015160272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015159888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015159696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015157200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015160080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015160464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015159504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029300496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029300688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129015158352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029301072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029302032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029301648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029301456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029300304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029301840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029303376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029304336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029303952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029303760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029301264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029304144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029304528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029305488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029305104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029304912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029302416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029305296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029305680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029306640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029302224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029303184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029302800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029302608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029300880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029302992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029306256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029306064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029303568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029306448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029306832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029307792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029307408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029307216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029304720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029307600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029307984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029308944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029308560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029308368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029305872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029308752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029309136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029310096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029309712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029309520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029307024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029309904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029310288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029311248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029310864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029310672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029308176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029311056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029311440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029312400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029312016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029311824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029309328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029312208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029312592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029313552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029313168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029312976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029310480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029313360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029313744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029314704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029314320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029314128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029311632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029314512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029314896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029315856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029315472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029315280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029312784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029315664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029316048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029315088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029313936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107206224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029316432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129029316240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107206800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107207760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107207376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107207184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107206416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107207568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107207952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107208912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107208528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107208336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107206608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107208720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107209104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107210064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107209680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107209488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107206992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107209872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107210256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107211216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107210832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107210640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107208144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107211024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107211408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107212368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107211984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107211792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107209296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107212176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107212560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107213520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107213136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107212944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107210448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107213328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107214864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107215824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107215440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107215248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107212752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107215632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107216016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107216976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107216592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107216400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107213904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107216784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107217168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107218128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107213712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107214672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107214288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107214096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107211600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107214480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107217744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107217552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107215056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107217936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107218320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107219280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107218896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107218704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107216208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107219088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107219472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107220432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107220048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107219856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107217360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107220240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107220624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107221584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107221200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107221008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107218512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107221392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107221776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107220816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107221968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107219664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107222352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129107222160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228775888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228776848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228776464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228776272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228775696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228776656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228777040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228778000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228777616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228777424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228775504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228777808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228778960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228779920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228779536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129228780496: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ TFLite model saved to: C:\Users\SAHAN\Desktop\My Part Mid Demo 02\CNN\Models\resnet_quantized.tflite
# ✅ History saved to: C:\Users\SAHAN\Desktop\My Part Mid Demo 02\CNN\Models\training_history_resnet.pickle
