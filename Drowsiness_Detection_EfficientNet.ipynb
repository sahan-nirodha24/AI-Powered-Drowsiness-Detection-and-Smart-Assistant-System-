# %% [markdown]
# # 🚗 Driver Drowsiness Detection System
# ## Model Architecture: EfficientNetV2B0 (Transfer Learning)
#
# This notebook implements a deep learning solution for detecting driver drowsiness using computer vision. The system is trained on an expanded dataset of **12,000 images** and utilizes **EfficientNetV2B0** via transfer learning to achieve high accuracy and robustness.
#
# ### ✨ Key Upgrades & Features:
# - **Data Scaling & Augmentation**: Dynamic brightness and spatial augmentations to handle varying lighting conditions inside a vehicle.
# - **Hard Negative Mining**: Integration of **Categorical Focal Crossentropy loss** to significantly reduce False Positives and False Negatives.
# - **Advanced Fine-Tuning**: Strategic unfreezing of deep layers coupled with L2 Regularization and Learning Rate Schedulers.
#
# ---
# ### 📋 Complete Analysis Workflow Index
#
# #### Part 1: Dataset Understanding (Basic Check)
# 1. **Structure & Distribution**: Counting images per class/split.
# 2. **Resolution & Color**: Verifying dimensions and channel counts.
#
# #### Part 2: Detailed EDA
# 3. **Visual EDA**: Inspecting samples, face visibility, and variations.
# 4. **Statistical EDA**: Pixel distributions, brightness, and blur detection.
#
# #### Part 3: Feature Encoding
# 5. **Label Encoding**: Converting text labels to Binary (0/1) and One-Hot vectors.
#
# #### Part 4: Data Preprocessing
# 6. **Resizing & Normalization**: Standardizing to 224x224 and scaling pixel values.
# 7. **Data Augmentation**: Enhancing dataset variety.
#
# #### Part 5: Dataset Splitting & Loading
# 8. **Generators**: Loading Train/Val/Test splits (70/15/15 ratio).
#
# #### Part 6: Model Building & Architecture
# 9. **Model Preparation**: Building EfficientNetV2B0 base with custom classification head.
#
# #### Part 7: Model Training
# 10. **Phase 1 Training**: Training Classification Head.
# 11. **Phase 2 Fine-Tuning**: Deep layer unfreezing and training with low LR.
#
# #### Part 8: Model Evaluation & Interpretation
# 12. **Evaluation Metrics**: Precision, Recall, F1, Accuracy.
# 13. **Confusion Matrix**: Visualizing misclassifications and analyzing Failed Cases.
#
# #### Part 9: Exporting
# 14. **Keras & TFLite**: Saving models for production and edge deployment (Raspberry Pi/Mobile).

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import pandas as pd
import pickle
import tensorflow as tf
from collections import Counter
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.applications import EfficientNetV2B0
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, Flatten, Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Output Style
plt.style.use('ggplot')

# Define paths
BASE_DIR = Path(r"c:\Users\SAHAN\Desktop\CNN\Processed_Dataset")
TRAIN_DIR = BASE_DIR / "train"
VAL_DIR = BASE_DIR / "val"
TEST_DIR = BASE_DIR / "test"

CATEGORIES = ["drowsy", "non-drowsy"]
TARGET_SIZE = (224, 224)
BATCH_SIZE = 32

# %% [markdown]
# # Part 1: Dataset Understanding

# %%
stats = []

for split in ["train", "val", "test"]:
    for category in CATEGORIES:
        folder = BASE_DIR / split / category
        count = len(list(folder.glob("*")))
        stats.append({
            "Split": split,
            "Category": category,
            "Count": count
        })

df_stats = pd.DataFrame(stats)
print("Dataset Statistics:")
print(df_stats)

# Visualize
df_stats.pivot(index="Split", columns="Category", values="Count").plot(kind="bar", stacked=True, figsize=(10, 6))
plt.title("Image Distribution per Split")
plt.ylabel("Number of Images")
plt.show()
# Out:
# Dataset Statistics:
#    Split    Category  Count
# 0  train      drowsy   4200
# 1  train  non-drowsy   4200
# 2    val      drowsy    900
# 3    val  non-drowsy    900
# 4   test      drowsy    900
# 5   test  non-drowsy    900

# %% [markdown]
# ## 1.2 Image Resolution and Color Space Analysis

# %%
# Sample analysis (iterating through training set)
resolutions = []
channels = []
print("Scanning the entire dataset for property check...")

sample_count = 0
for category in CATEGORIES:
    folder = TRAIN_DIR / category
    for img_path in folder.glob("*"):
        # if sample_count >= 12000: break
        img = cv2.imread(str(img_path))
        if img is not None:
            resolutions.append(img.shape[:2])
            channels.append(img.shape[2] if len(img.shape) > 2 else 1)
            sample_count += 1

print(f"Resolution Check: {Counter([str(r) for r in resolutions])}")
print(f"Channel Check (OpenCV loads): {Counter(channels)}")
# Out:
# Scanning the entire dataset for property check...
# Resolution Check: Counter({'(224, 224)': 8400})
# Channel Check (OpenCV loads): Counter({3: 8400})

# %% [markdown]
# # Part 2: Detailed Exploratory Data Analysis (EDA)

# %%
def clean_filename_info(filename):
    has_glasses = "with_glasses" in filename
    origin = "BW" if "Black&White" in filename else "Color"
    return origin, has_glasses

def view_grid(category, samples=5):
    folder = TRAIN_DIR / category
    all_files = list(folder.glob("*"))
    selected = np.random.choice(all_files, samples, replace=False)
    
    plt.figure(figsize=(15, 4))
    plt.suptitle(f"Class: {category.upper()}", fontsize=14)
    
    for i, path in enumerate(selected):
        img = cv2.imread(str(path))
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        origin, glasses = clean_filename_info(path.name)
        plt.subplot(1, samples, i+1)
        plt.imshow(img, cmap='gray' if origin=='BW' else None)
        plt.axis('off')
        plt.title(f"{origin} | {'Glasses' if glasses else 'No Glass'}", fontsize=10)
    plt.show()

view_grid("drowsy", 6)
view_grid("non-drowsy", 6)

# %% [markdown]
# ## 2.1 Statistical Plot: Brightness Distribution
# Checking if there is a significant lighting difference between Drowsy and Non-Drowsy classes.

# %%
brightness_values = {"drowsy": [], "non-drowsy": []}

print("Calculating brightness stats for the entire dataset...")
for category in CATEGORIES:
    folder = TRAIN_DIR / category
    for i, img_path in enumerate(folder.glob("*")):
        # if i >= 12000: break
        img = cv2.imread(str(img_path))
        if img is not None:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            brightness_values[category].append(np.mean(gray))

plt.figure(figsize=(10, 5))
sns.kdeplot(brightness_values["drowsy"], fill=True, label="Drowsy", color="red")
sns.kdeplot(brightness_values["non-drowsy"], fill=True, label="Non-Drowsy", color="blue")
plt.title("Brightness Distribution Analysis")
plt.xlabel("Average Pixel Intensity (Brightness)")
plt.legend()
plt.show()
# Out:
# Calculating brightness stats for the entire dataset...

# %%
# Gather Metadata
data = []
for category in ["drowsy", "non-drowsy"]:
    folder = TRAIN_DIR / category
    for filepath in folder.glob("*"):
        origin, has_glasses = clean_filename_info(filepath.name)
        data.append({"category": category, "has_glasses": has_glasses})

df = pd.DataFrame(data)
summary = df.groupby(["category", "has_glasses"]).size().reset_index(name="count")
print("Sub-category Distribution in Train Set:")
print(summary)
# Out:
# Sub-category Distribution in Train Set:
#      category  has_glasses  count
# 0      drowsy        False   2095
# 1      drowsy         True   2105
# 2  non-drowsy        False   2122
# 3  non-drowsy         True   2078

# %% [markdown]
# # Part 3: Feature Encoding (Enhanced)

# %%
labels = ["drowsy", "non-drowsy"]
label_map = {label: i for i, label in enumerate(labels)}
print(f"Binary Mapping: {label_map}")

# 1. Visualizing One-Hot Vectors Table
demo_encoding = pd.DataFrame({
    'Class': ['drowsy', 'non-drowsy'],
    'Binary': [0, 1],
    'One-Hot': [str(to_categorical(0, 2)), str(to_categorical(1, 2))]
})
print("\nEncoding Reference Table:")
print(demo_encoding)

# 2. Visualizing Class Balance using Encoded Labels
train_drowsy_count = len(list((TRAIN_DIR / "drowsy").glob("*")))
train_non_drowsy_count = len(list((TRAIN_DIR / "non-drowsy").glob("*")))

plt.figure(figsize=(6, 4))
plt.bar(['Label 0 (Drowsy)', 'Label 1 (Non-Drowsy)'], 
        [train_drowsy_count, train_non_drowsy_count], 
        color=['salmon', 'skyblue'])
plt.title("Class Balance by Encoded Label (Training Set)")
plt.ylabel("Count")
plt.show()
# Out:
# Binary Mapping: {'drowsy': 0, 'non-drowsy': 1}
#
# Encoding Reference Table:
#         Class  Binary  One-Hot
# 0      drowsy       0  [1. 0.]
# 1  non-drowsy       1  [0. 1.]

# %%
# 3. Sample Images with Vector Labels
plt.figure(figsize=(12, 4))
plt.suptitle("Data as Seen by Model: Image + One-Hot Vector", fontsize=14)

for i, category in enumerate(CATEGORIES):
    folder = TRAIN_DIR / category
    img_path = list(folder.glob("*"))[0]
    img = cv2.imread(str(img_path))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    encoded_label = to_categorical(label_map[category], num_classes=2)
    
    plt.subplot(1, 2, i+1)
    plt.imshow(img, cmap='gray' if "Black" in str(img_path) else None)
    plt.title(f"Class: {category}\nVector: {encoded_label}")
    plt.axis('off')
plt.show()

# %% [markdown]
# # Part 4: Data Preprocessing & Visualization

# %%
# Setup Generators with EfficientNetV2B0 Preprocessing (Correct for Transfer Learning)
from tensorflow.keras.applications.efficientnet import preprocess_input

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input, # Scales to [-1, 1]
    rotation_range=20,       # Rotation
    width_shift_range=0.2,   # Horizontal Shift
    height_shift_range=0.2,  # Vertical Shift
    zoom_range=0.2,          # Zoom
    brightness_range=[0.8, 1.2], # Added brightness range to handle lighting variations
    horizontal_flip=True,    # Flip
    fill_mode='nearest'      
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

print("Augmentation Configuration Set (EfficientNetV2B0 [-1, 1]).")
# Out:
# Augmentation Configuration Set (EfficientNetV2B0 [-1, 1]).

# %% [markdown]
# ## 4.1 Visualize Augmentation Effects
# Checking how "Rotation", "Zoom", and "Shift" actually affect our images.

# %%
def visualize_augmentation(category):
    # Pick a random image
    folder = TRAIN_DIR / category
    img_path = list(folder.glob("*"))[0]
    img = load_img(str(img_path), target_size=TARGET_SIZE)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0
    plt.figure(figsize=(15, 6))
    plt.suptitle(f"Augmentation Random Samples: {category.upper()}", fontsize=16)

    # Plot Original
    plt.subplot(2, 4, 1)
    plt.imshow(img)
    plt.title("Original")
    plt.axis('off')

    # Plot Augmented Versions
    for batch in train_datagen.flow(x, batch_size=1):
        plt.subplot(2, 4, i + 2)
        img_aug = batch[0] 
        # Rescale back to 0-1 for visualization if needed (efficientnet is -1 to 1)
        img_viz = img_aug - np.min(img_aug)
        img_viz = img_viz / (np.max(img_viz) + 1e-5)
        plt.imshow(img_viz)
        plt.title(f"Augment {i+1}")
        plt.axis('off')
        i += 1
        if i >= 7: break
    plt.show()

visualize_augmentation("drowsy")

# %% [markdown]
# ## 4.2 Using EfficientNetV2B0 Preprocessing
# Note: The values are preserved perfectly for this network, as standard ImageNet scaling layers are already embedded directly into the base layers of EfficientNetV2B0.

# %%
# Preprocessing Analysis
sample_path = list((TRAIN_DIR / "drowsy").glob("*"))[0]
original_img = cv2.imread(str(sample_path))
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

# Apply Preprocessing manually
preprocessed_img = cv2.resize(original_img, TARGET_SIZE)
preprocessed_img = preprocessed_img.astype("float32")
preprocessed_img = preprocess_input(preprocessed_img) # [-1, 1]

plt.figure(figsize=(12, 5))

# 1. Pixel Value Histogram (Normalization Check)
plt.subplot(1, 2, 1)
sns.histplot(original_img.flatten(), color='red', label='Original (0-255)', kde=True, stat="density", alpha=0.3)
sns.histplot(preprocessed_img.flatten(), color='blue', label='Preprocessed (-1 to 1)', kde=True, stat="density", alpha=0.3)
plt.title("Pixel Intensity Distribution Check")
plt.legend()

# 2. Input Tensor Heatmap (What the CNN 'sees' in shape)
plt.subplot(1, 2, 2)
heatmap_img = np.mean(preprocessed_img, axis=2)
sns.heatmap(heatmap_img, cmap="viridis", cbar=True)
plt.title("Input Tensor Heatmap (Mean Channel)")
plt.axis('off')

plt.show()

# %% [markdown]
# # Part 5: Dataset Splitting & Loading (Enhanced)

# %%
print("Loading Data from Directory Structure...")

# 1. Load Training Set
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# 2. Load Validation Set
validation_generator = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False 
)

# 3. Load Test Set
test_generator = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"\nClass Indices: {train_generator.class_indices}")
# Out:
# Loading Data from Directory Structure...
# Found 8400 images belonging to 2 classes.
# Found 1800 images belonging to 2 classes.
# Found 1800 images belonging to 2 classes.
#
# Class Indices: {'drowsy': 0, 'non-drowsy': 1}

# %% [markdown]
# ## 5.1 Visualize Generator Output (Batch Verification)

# %%
# Fetch a batch
x_batch, y_batch = next(train_generator)

# Visualize 8 random images from the batch
plt.figure(figsize=(15, 8))
plt.suptitle("Generator Batch Visualization (Correct Labels?)", fontsize=16)

class_names = list(train_generator.class_indices.keys())

for i in range(8):
    plt.subplot(2, 4, i+1)
    # Convert back to 0-1 for display
    img_disp = x_batch[i] - np.min(x_batch[i])
    img_disp = img_disp / (np.max(img_disp) + 1e-5)
    plt.imshow(img_disp)
    
    # Decode One-Hot Label
    label_idx = np.argmax(y_batch[i])
    label_name = class_names[label_idx]
    
    plt.title(f"Label: {label_name}\n{y_batch[i]}")
    plt.axis('off')
plt.show()

# %% [markdown]
# ## 5.2 Split Distribution Visualization

# %%
counts = [train_generator.samples, validation_generator.samples, test_generator.samples]
labels = [f'Train ({counts[0]})', f'Val ({counts[1]})', f'Test ({counts[2]})']
colors = ['#ff9999', '#66b3ff', '#99ff99']

plt.figure(figsize=(7, 7))
plt.pie(counts, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, explode=(0.05, 0, 0))
plt.title("Final Dataset Split Distribution")
plt.show()

# %% [markdown]
# # Part 6: Model Architecture & Transfer Learning Setup

# %%
from tensorflow.keras.regularizers import l2
def build_efficientnet_model(input_shape=(224, 224, 3), num_classes=2):
    base_model = EfficientNetV2B0(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x) 
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

model = build_efficientnet_model()
INIT_LR = 1e-4
opt = Adam(learning_rate=INIT_LR)
model.compile(loss=CategoricalFocalCrossentropy(), optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ## 6.1 Visualize Model Complexity
# Visualizing the parameters per layer to understand the model structure.

# %%
# Visualizing Transfer Learning Layers
layer_names = []
layer_params = []

for layer in model.layers:
    layer_names.append(layer.name)
    layer_params.append(layer.count_params())

# Show only top 10 heaviest layers + last 3 custom layers
indices = np.argsort(layer_params)[-10:]
sorted_names = [layer_names[i] for i in indices]
sorted_params = [layer_params[i] for i in indices]

# Add Custom Head
custom_names = [l.name for l in model.layers[-3:]]
custom_params = [l.count_params() for l in model.layers[-3:]]

plt.figure(figsize=(12, 6))
plt.barh(sorted_names + custom_names, sorted_params + custom_params, color='purple')
plt.xlabel("Number of Parameters")
plt.title("Model Complexity: Top Layers + Custom Head")
plt.grid(axis='x')
plt.show()

print(f"Total Parameters: {model.count_params():,}")
print(f"Trainable Parameters: {np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Total Parameters: 6,083,538
# Trainable Parameters: 164,226

# %% [markdown]
# # Part 7: Hard Negative Mining & Model Training (With Fine-Tuning)

# %%
# --- TRAINING PHASE 1: Train Head Only ---
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=12,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2,
    patience=3, 
    min_lr=1e-6,
    verbose=1
)

from sklearn.utils import class_weight
# --- TRAINING PHASE 1: Train Head Only ---
print("Starting Training Phase 1 (Head Only)...")
# NEW: Compute class weights to handle dataset imbalance
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights_dict = dict(enumerate(class_weights))
print(f"Computed Class Weights: {class_weights_dict}")
history_1 = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    epochs=10, # Initial training
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights_dict # <--- NEW: Pass calculated weights to the model
)

# --- TRAINING PHASE 2: Fine-Tuning ---
print("\nStarting Training Phase 2 (Fine-Tuning)...")
# 1. Unfreeze the base model
model.trainable = True
# 2. Freeze earlier layers 
# NEW: Increased frozen layers from 100 to 120 to reduce overfitting during fine-tuning
FINE_TUNE_AT = 180
for layer in model.layers[:FINE_TUNE_AT]:
    layer.trainable = False
print(f"Layers frozen: {FINE_TUNE_AT}. Layers trainable: {len(model.layers) - FINE_TUNE_AT}")
# 3. Re-compile with label smoothing and very low learning rate
model.compile(
    loss=CategoricalFocalCrossentropy(), # <--- NEW: Re-applied label smoothing
    optimizer=Adam(learning_rate=1e-5), 
    metrics=["accuracy"]
)
# 4. Continue Training
total_epochs = 100 # 30 + 20
history_fine = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    initial_epoch=history_1.epoch[-1],
    epochs=total_epochs,
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights_dict # <--- NEW: Pass class weights to fine-tuning phase as well
)
print("Training Completed (Fine-Tuning).")

# Merge Histories for Plotting
acc = history_1.history['accuracy'] + history_fine.history['accuracy']
val_acc = history_1.history['val_accuracy'] + history_fine.history['val_accuracy']
loss = history_1.history['loss'] + history_fine.history['loss']
val_loss = history_1.history['val_loss'] + history_fine.history['val_loss']

# Create a dummy history object wrapper for compatibility with downstream plotting code
class CombinedHistory:
    def __init__(self):
        self.history = {
            'accuracy': acc,
            'val_accuracy': val_acc,
            'loss': loss,
            'val_loss': val_loss
        }
history = CombinedHistory()
# Out:
# Starting Training Phase 1 (Head Only)...
# Computed Class Weights: {0: np.float64(1.0), 1: np.float64(1.0)}
# C:\Users\SAHAN\AppData\Roaming\Python\Python313\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 119s 430ms/step - accuracy: 0.6226 - loss: 1.5365 - val_accuracy: 0.7818 - val_loss: 0.8846 - learning_rate: 1.0000e-04
# Epoch 2/10
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 1:09 267ms/step - accuracy: 0.7188 - loss: 0.8832
# C:\Users\SAHAN\AppData\Roaming\Python\Python313\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 55ms/step - accuracy: 0.7188 - loss: 0.8832 - val_accuracy: 0.7824 - val_loss: 0.8811 - learning_rate: 1.0000e-04
# Epoch 3/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 112s 428ms/step - accuracy: 0.7321 - loss: 0.5510 - val_accuracy: 0.8041 - val_loss: 0.3110 - learning_rate: 1.0000e-04
# Epoch 4/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 55ms/step - accuracy: 0.6250 - loss: 0.3183 - val_accuracy: 0.8047 - val_loss: 0.3098 - learning_rate: 1.0000e-04
# Epoch 5/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 120s 459ms/step - accuracy: 0.7802 - loss: 0.1994 - val_accuracy: 0.8298 - val_loss: 0.1211 - learning_rate: 1.0000e-04
# Epoch 6/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.6562 - loss: 0.1286 - val_accuracy: 0.8320 - val_loss: 0.1206 - learning_rate: 1.0000e-04
# Epoch 7/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 117s 445ms/step - accuracy: 0.8188 - loss: 0.0871 - val_accuracy: 0.8672 - val_loss: 0.0618 - learning_rate: 1.0000e-04
# Epoch 8/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.8750 - loss: 0.0628 - val_accuracy: 0.8677 - val_loss: 0.0618 - learning_rate: 1.0000e-04
# Epoch 9/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 119s 454ms/step - accuracy: 0.8262 - loss: 0.0522 - val_accuracy: 0.8800 - val_loss: 0.0426 - learning_rate: 1.0000e-04
# Epoch 10/10
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.9062 - loss: 0.0400 - val_accuracy: 0.8783 - val_loss: 0.0425 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 10.
#
# Starting Training Phase 2 (Fine-Tuning)...
# Layers frozen: 180. Layers trainable: 94
# Epoch 10/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 133s 484ms/step - accuracy: 0.8468 - loss: 0.0427 - val_accuracy: 0.8789 - val_loss: 0.0406 - learning_rate: 1.0000e-05
# Epoch 11/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 59ms/step - accuracy: 0.8125 - loss: 0.0417 - val_accuracy: 0.8789 - val_loss: 0.0406 - learning_rate: 1.0000e-05
# Epoch 12/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 115s 437ms/step - accuracy: 0.8556 - loss: 0.0411 - val_accuracy: 0.8817 - val_loss: 0.0391 - learning_rate: 1.0000e-05
# Epoch 13/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.8125 - loss: 0.0412 - val_accuracy: 0.8817 - val_loss: 0.0391 - learning_rate: 1.0000e-05
# Epoch 14/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 120s 456ms/step - accuracy: 0.8506 - loss: 0.0403 - val_accuracy: 0.8834 - val_loss: 0.0379 - learning_rate: 1.0000e-05
# Epoch 15/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.8750 - loss: 0.0406 - val_accuracy: 0.8823 - val_loss: 0.0379 - learning_rate: 1.0000e-05
# Epoch 16/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 118s 448ms/step - accuracy: 0.8605 - loss: 0.0388 - val_accuracy: 0.8884 - val_loss: 0.0370 - learning_rate: 1.0000e-05
# Epoch 17/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 60ms/step - accuracy: 0.8125 - loss: 0.0415 - val_accuracy: 0.8890 - val_loss: 0.0370 - learning_rate: 1.0000e-05
# Epoch 18/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 119s 454ms/step - accuracy: 0.8602 - loss: 0.0378 - val_accuracy: 0.8884 - val_loss: 0.0359 - learning_rate: 1.0000e-05
# Epoch 19/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.9062 - loss: 0.0381 - val_accuracy: 0.8878 - val_loss: 0.0359 - learning_rate: 1.0000e-05
# Epoch 20/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 117s 445ms/step - accuracy: 0.8596 - loss: 0.0372 - val_accuracy: 0.8945 - val_loss: 0.0351 - learning_rate: 1.0000e-05
# Epoch 21/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.8750 - loss: 0.0405 - val_accuracy: 0.8934 - val_loss: 0.0351 - learning_rate: 1.0000e-05
# Epoch 22/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 117s 444ms/step - accuracy: 0.8627 - loss: 0.0363 - val_accuracy: 0.8973 - val_loss: 0.0342 - learning_rate: 1.0000e-05
# Epoch 23/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 59ms/step - accuracy: 0.9062 - loss: 0.0341 - val_accuracy: 0.8951 - val_loss: 0.0342 - learning_rate: 1.0000e-05
# Epoch 24/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 119s 455ms/step - accuracy: 0.8651 - loss: 0.0354 - val_accuracy: 0.8923 - val_loss: 0.0337 - learning_rate: 1.0000e-05
# Epoch 25/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 20s 75ms/step - accuracy: 0.8438 - loss: 0.0380 - val_accuracy: 0.8923 - val_loss: 0.0337 - learning_rate: 1.0000e-05
# Epoch 26/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 118s 452ms/step - accuracy: 0.8679 - loss: 0.0345 - val_accuracy: 0.8962 - val_loss: 0.0331 - learning_rate: 1.0000e-05
# Epoch 27/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 1.0000 - loss: 0.0271 - val_accuracy: 0.8945 - val_loss: 0.0331 - learning_rate: 1.0000e-05
# Epoch 28/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 117s 448ms/step - accuracy: 0.8682 - loss: 0.0341 - val_accuracy: 0.9023 - val_loss: 0.0323 - learning_rate: 1.0000e-05
# Epoch 29/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.8438 - loss: 0.0357 - val_accuracy: 0.9029 - val_loss: 0.0323 - learning_rate: 1.0000e-05
# Epoch 30/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 116s 444ms/step - accuracy: 0.8674 - loss: 0.0334 - val_accuracy: 0.9001 - val_loss: 0.0318 - learning_rate: 1.0000e-05
# Epoch 31/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.7812 - loss: 0.0347 - val_accuracy: 0.9001 - val_loss: 0.0318 - learning_rate: 1.0000e-05
# Epoch 32/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 119s 455ms/step - accuracy: 0.8761 - loss: 0.0328 - val_accuracy: 0.9001 - val_loss: 0.0311 - learning_rate: 1.0000e-05
# Epoch 33/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.8438 - loss: 0.0387 - val_accuracy: 0.9012 - val_loss: 0.0311 - learning_rate: 1.0000e-05
# Epoch 34/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 129s 494ms/step - accuracy: 0.8701 - loss: 0.0326 - val_accuracy: 0.9007 - val_loss: 0.0307 - learning_rate: 1.0000e-05
# Epoch 35/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 25s 94ms/step - accuracy: 0.8125 - loss: 0.0323 - val_accuracy: 0.9012 - val_loss: 0.0307 - learning_rate: 1.0000e-05
# Epoch 36/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 198s 754ms/step - accuracy: 0.8701 - loss: 0.0322 - val_accuracy: 0.9023 - val_loss: 0.0303 - learning_rate: 1.0000e-05
# Epoch 37/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 25s 96ms/step - accuracy: 0.8125 - loss: 0.0390 - val_accuracy: 0.8996 - val_loss: 0.0303 - learning_rate: 1.0000e-05
# Epoch 38/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 201s 767ms/step - accuracy: 0.8707 - loss: 0.0319 - val_accuracy: 0.9074 - val_loss: 0.0298 - learning_rate: 1.0000e-05
# Epoch 39/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.9062 - loss: 0.0285 - val_accuracy: 0.9062 - val_loss: 0.0298 - learning_rate: 1.0000e-05
# Epoch 40/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 160s 612ms/step - accuracy: 0.8744 - loss: 0.0312 - val_accuracy: 0.9068 - val_loss: 0.0296 - learning_rate: 1.0000e-05
# Epoch 41/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.8750 - loss: 0.0279 - val_accuracy: 0.9074 - val_loss: 0.0295 - learning_rate: 1.0000e-05
# Epoch 42/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.8751 - loss: 0.0309 - val_accuracy: 0.9046 - val_loss: 0.0291 - learning_rate: 1.0000e-05
# Epoch 43/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 14s 54ms/step - accuracy: 1.0000 - loss: 0.0277 - val_accuracy: 0.9046 - val_loss: 0.0291 - learning_rate: 1.0000e-05
# Epoch 44/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 111s 425ms/step - accuracy: 0.8755 - loss: 0.0305 - val_accuracy: 0.9051 - val_loss: 0.0290 - learning_rate: 1.0000e-05
# Epoch 45/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.9375 - loss: 0.0289 - val_accuracy: 0.9051 - val_loss: 0.0290 - learning_rate: 1.0000e-05
# Epoch 46/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 118s 451ms/step - accuracy: 0.8779 - loss: 0.0301 - val_accuracy: 0.9068 - val_loss: 0.0286 - learning_rate: 1.0000e-05
# Epoch 47/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 14s 54ms/step - accuracy: 0.8125 - loss: 0.0353 - val_accuracy: 0.9079 - val_loss: 0.0286 - learning_rate: 1.0000e-05
# Epoch 48/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 119s 453ms/step - accuracy: 0.8762 - loss: 0.0299 - val_accuracy: 0.9096 - val_loss: 0.0282 - learning_rate: 1.0000e-05
# Epoch 49/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 59ms/step - accuracy: 0.9062 - loss: 0.0306 - val_accuracy: 0.9090 - val_loss: 0.0282 - learning_rate: 1.0000e-05
# Epoch 50/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 120s 458ms/step - accuracy: 0.8766 - loss: 0.0297 - val_accuracy: 0.9062 - val_loss: 0.0280 - learning_rate: 1.0000e-05
# Epoch 51/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.8750 - loss: 0.0282 - val_accuracy: 0.9062 - val_loss: 0.0280 - learning_rate: 1.0000e-05
# Epoch 52/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 119s 455ms/step - accuracy: 0.8752 - loss: 0.0294 - val_accuracy: 0.9018 - val_loss: 0.0276 - learning_rate: 1.0000e-05
# Epoch 53/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 60ms/step - accuracy: 0.9375 - loss: 0.0270 - val_accuracy: 0.9012 - val_loss: 0.0276 - learning_rate: 1.0000e-05
# Epoch 54/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 121s 462ms/step - accuracy: 0.8782 - loss: 0.0289 - val_accuracy: 0.9102 - val_loss: 0.0273 - learning_rate: 1.0000e-05
# Epoch 55/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.9062 - loss: 0.0249 - val_accuracy: 0.9096 - val_loss: 0.0273 - learning_rate: 1.0000e-05
# Epoch 56/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 119s 454ms/step - accuracy: 0.8727 - loss: 0.0290 - val_accuracy: 0.9074 - val_loss: 0.0271 - learning_rate: 1.0000e-05
# Epoch 57/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.8750 - loss: 0.0301 - val_accuracy: 0.9085 - val_loss: 0.0271 - learning_rate: 1.0000e-05
# Epoch 58/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 121s 460ms/step - accuracy: 0.8840 - loss: 0.0284 - val_accuracy: 0.9135 - val_loss: 0.0269 - learning_rate: 1.0000e-05
# Epoch 59/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 59ms/step - accuracy: 0.8125 - loss: 0.0331 - val_accuracy: 0.9129 - val_loss: 0.0269 - learning_rate: 1.0000e-05
# Epoch 60/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 120s 456ms/step - accuracy: 0.8760 - loss: 0.0282 - val_accuracy: 0.9118 - val_loss: 0.0266 - learning_rate: 1.0000e-05
# Epoch 61/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.7500 - loss: 0.0359 - val_accuracy: 0.9118 - val_loss: 0.0266 - learning_rate: 1.0000e-05
# Epoch 62/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 120s 457ms/step - accuracy: 0.8780 - loss: 0.0282 - val_accuracy: 0.9157 - val_loss: 0.0264 - learning_rate: 1.0000e-05
# Epoch 63/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.8750 - loss: 0.0314 - val_accuracy: 0.9157 - val_loss: 0.0264 - learning_rate: 1.0000e-05
# Epoch 64/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 120s 459ms/step - accuracy: 0.8817 - loss: 0.0279 - val_accuracy: 0.9180 - val_loss: 0.0260 - learning_rate: 1.0000e-05
# Epoch 65/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 59ms/step - accuracy: 0.8438 - loss: 0.0301 - val_accuracy: 0.9185 - val_loss: 0.0260 - learning_rate: 1.0000e-05
# Epoch 66/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 120s 458ms/step - accuracy: 0.8831 - loss: 0.0274 - val_accuracy: 0.9163 - val_loss: 0.0259 - learning_rate: 1.0000e-05
# Epoch 67/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 60ms/step - accuracy: 0.7812 - loss: 0.0303 - val_accuracy: 0.9157 - val_loss: 0.0259 - learning_rate: 1.0000e-05
# Epoch 68/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 122s 465ms/step - accuracy: 0.8835 - loss: 0.0273 - val_accuracy: 0.9141 - val_loss: 0.0256 - learning_rate: 1.0000e-05
# Epoch 69/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.9375 - loss: 0.0251 - val_accuracy: 0.9141 - val_loss: 0.0256 - learning_rate: 1.0000e-05
# Epoch 70/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 124s 471ms/step - accuracy: 0.8866 - loss: 0.0271 - val_accuracy: 0.9235 - val_loss: 0.0253 - learning_rate: 1.0000e-05
# Epoch 71/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 60ms/step - accuracy: 0.8750 - loss: 0.0306 - val_accuracy: 0.9241 - val_loss: 0.0253 - learning_rate: 1.0000e-05
# Epoch 72/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 120s 456ms/step - accuracy: 0.8849 - loss: 0.0270 - val_accuracy: 0.9230 - val_loss: 0.0252 - learning_rate: 1.0000e-05
# Epoch 73/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.9062 - loss: 0.0258 - val_accuracy: 0.9230 - val_loss: 0.0252 - learning_rate: 1.0000e-05
# Epoch 74/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 116s 442ms/step - accuracy: 0.8854 - loss: 0.0267 - val_accuracy: 0.9169 - val_loss: 0.0250 - learning_rate: 1.0000e-05
# Epoch 75/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.8125 - loss: 0.0309 - val_accuracy: 0.9174 - val_loss: 0.0250 - learning_rate: 1.0000e-05
# Epoch 76/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 116s 443ms/step - accuracy: 0.8805 - loss: 0.0268 - val_accuracy: 0.9141 - val_loss: 0.0249 - learning_rate: 1.0000e-05
# Epoch 77/100
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 1:16 293ms/step - accuracy: 0.8750 - loss: 0.0270
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 61ms/step - accuracy: 0.8750 - loss: 0.0270 - val_accuracy: 0.9141 - val_loss: 0.0249 - learning_rate: 1.0000e-05
# Epoch 78/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 115s 437ms/step - accuracy: 0.8868 - loss: 0.0264 - val_accuracy: 0.9180 - val_loss: 0.0248 - learning_rate: 2.0000e-06
# Epoch 79/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.8750 - loss: 0.0239 - val_accuracy: 0.9180 - val_loss: 0.0248 - learning_rate: 2.0000e-06
# Epoch 80/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 114s 436ms/step - accuracy: 0.8843 - loss: 0.0263 - val_accuracy: 0.9169 - val_loss: 0.0248 - learning_rate: 2.0000e-06
# Epoch 81/100
#   1/262 ━━━━━━━━━━━━━━━━━━━━ 1:13 282ms/step - accuracy: 0.9375 - loss: 0.0267
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1e-06.
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.9375 - loss: 0.0267 - val_accuracy: 0.9169 - val_loss: 0.0248 - learning_rate: 2.0000e-06
# Epoch 82/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 117s 448ms/step - accuracy: 0.8854 - loss: 0.0264 - val_accuracy: 0.9180 - val_loss: 0.0248 - learning_rate: 1.0000e-06
# Epoch 83/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 59ms/step - accuracy: 0.8438 - loss: 0.0290 - val_accuracy: 0.9180 - val_loss: 0.0248 - learning_rate: 1.0000e-06
# Epoch 84/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 116s 443ms/step - accuracy: 0.8893 - loss: 0.0263 - val_accuracy: 0.9169 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 85/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 56ms/step - accuracy: 0.6875 - loss: 0.0355 - val_accuracy: 0.9169 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 86/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 116s 443ms/step - accuracy: 0.8893 - loss: 0.0262 - val_accuracy: 0.9169 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 87/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.9375 - loss: 0.0257 - val_accuracy: 0.9169 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 88/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 116s 443ms/step - accuracy: 0.8899 - loss: 0.0261 - val_accuracy: 0.9169 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 89/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9688 - loss: 0.0234 - val_accuracy: 0.9169 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 90/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 117s 446ms/step - accuracy: 0.8865 - loss: 0.0262 - val_accuracy: 0.9152 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 91/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.8438 - loss: 0.0250 - val_accuracy: 0.9152 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 92/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 116s 443ms/step - accuracy: 0.8830 - loss: 0.0263 - val_accuracy: 0.9163 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 93/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.8750 - loss: 0.0248 - val_accuracy: 0.9163 - val_loss: 0.0247 - learning_rate: 1.0000e-06
# Epoch 94/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 115s 440ms/step - accuracy: 0.8861 - loss: 0.0263 - val_accuracy: 0.9157 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Epoch 95/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.9688 - loss: 0.0195 - val_accuracy: 0.9157 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Epoch 96/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 117s 446ms/step - accuracy: 0.8847 - loss: 0.0263 - val_accuracy: 0.9163 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Epoch 97/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9375 - loss: 0.0245 - val_accuracy: 0.9163 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Epoch 98/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 143s 545ms/step - accuracy: 0.8929 - loss: 0.0259 - val_accuracy: 0.9152 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Epoch 99/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.8438 - loss: 0.0297 - val_accuracy: 0.9157 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Epoch 100/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 221s 843ms/step - accuracy: 0.8840 - loss: 0.0263 - val_accuracy: 0.9180 - val_loss: 0.0246 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 100.
# Training Completed (Fine-Tuning).

# %% [markdown]
# ## 7.2 Enhanced History Visualization
# Plotting curves with markings for the Best Epoch (Lowest Validation Loss).

# %%
# Plot History with Best Epoch Marker
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

# Find Best Epoch
best_epoch = np.argmin(val_loss)
best_loss = val_loss[best_epoch]
best_acc = val_acc[best_epoch]

plt.figure(figsize=(14, 5))
plt.suptitle(f"Training Metrics (Best Epoch: {best_epoch+1})", fontsize=16)

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.scatter([best_epoch], [best_acc], color='green', marker='o', s=100, label=f'Best Val Acc: {best_acc:.2f}')
plt.plot([9, 9], plt.ylim(), label='Fine-Tuning Start', linestyle='--', color='purple')
plt.legend(loc='lower right')
plt.title('Accuracy')

# Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.scatter([best_epoch], [best_loss], color='red', marker='x', s=100, label=f'Best Val Loss: {best_loss:.2f}')
plt.axvline(best_epoch, color='gray', linestyle='--', alpha=0.5)
plt.plot([9, 9], plt.ylim(), label='Fine-Tuning Start', linestyle='--', color='purple')
plt.legend(loc='upper right')
plt.title('Loss')

plt.show()

# %% [markdown]
# # Part 8: Model Evaluation & Interpretation

# %%
print("Evaluating on Test Set...")
test_loss, test_acc = model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_acc:.4f}")

# Classification Report
test_generator.reset()
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# Confusion Matrix Heatmap
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix (Heatmap)')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.show()
# Out:
# Evaluating on Test Set...
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 27s 473ms/step - accuracy: 0.9078 - loss: 0.0251
#
# Test Accuracy: 0.9078
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 30s 486ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       drowsy       0.91      0.91      0.91       900
#   non-drowsy       0.91      0.91      0.91       900
#
#     accuracy                           0.91      1800
#    macro avg       0.91      0.91      0.91      1800
# weighted avg       0.91      0.91      0.91      1800

# %%
# ROC Curve Plot
fpr, tpr, thresholds = roc_curve(true_classes, predictions[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
print("Visualizing Misclassified Images (Sample Images)...")
errors = np.where(predicted_classes != true_classes)[0]

if len(errors) == 0:
    print("Amazing! No errors found on Test Set.")
else:
    # Show top 10 errors
    num_errors = min(10, len(errors))
    plt.figure(figsize=(20, 4))
    
    for i, error_idx in enumerate(errors[:num_errors]):
        img_path = test_generator.filepaths[error_idx]
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        true_label = class_labels[true_classes[error_idx]]
        pred_label = class_labels[predicted_classes[error_idx]]
        # Handle filename info safely
        if "Black" in img_path: origin = "BW"
        else: origin = "Color"
        
        plt.subplot(1, num_errors, i+1)
        # Use preprocess inverse for display
        plt.imshow(img, cmap='gray' if origin=='BW' else None)
        plt.axis('off')
        plt.title(f"True: {true_label}\nPred: {pred_label}", fontsize=8, color='red')
    plt.suptitle("Failure Analysis Examples", fontsize=14)
    plt.show()
# Out:
# Visualizing Misclassified Images (Sample Images)...

# %% [markdown]
# # Part 9: Saving Models

# %%
MODELS_DIR = BASE_DIR.parent / "Models"
MODELS_DIR.mkdir(parents=True, exist_ok=True)

# 1. Save Keras Model (.h5)
h5_path = MODELS_DIR / "drowsiness_model_efficientnet.h5"
model.save(str(h5_path))
print(f"✅ Keras model saved to: {h5_path}")

# 2. Convert to TensorFlow Lite (.tflite)
print("Converting to TFLite...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

tflite_path = MODELS_DIR / "efficientnet_quantized.tflite"
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)
print(f"✅ TFLite model saved to: {tflite_path}")

# 3. Save History (.pickle)
history_path = MODELS_DIR / "training_history_efficientnet.pickle"
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f)
print(f"✅ History saved to: {history_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Keras model saved to: c:\Users\SAHAN\Desktop\CNN\Models\drowsiness_model_efficientnet.h5
# Converting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\SAHAN\AppData\Local\Temp\tmp7dkzi5fz\assets
# INFO:tensorflow:Assets written to: C:\Users\SAHAN\AppData\Local\Temp\tmp7dkzi5fz\assets
# Saved artifact at 'C:\Users\SAHAN\AppData\Local\Temp\tmp7dkzi5fz'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   1693882285712: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   1693882284368: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   1693882703248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882711504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882699024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882703632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882697488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882708816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882699216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882711696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882697296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882701904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882701712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882707856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882697680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882703440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882707664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882706128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882285904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882707472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882280336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693878018768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693877842384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693877841616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882280144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882280528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882512400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882499344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882512592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882515088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882953808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882953424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882953616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882951504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882953232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882955536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882953040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882955152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882949584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882951312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882950928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882949200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882951696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882947280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882949008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882947472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882946704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882946896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882944784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882945360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882945168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882943248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882944592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882942480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882943056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882948816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882955728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882942864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882956496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882955920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882942672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882957456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882956688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882957648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882956112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882944976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882956304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882957072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693882956880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884088784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884089168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884088976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884089936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884089360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884089552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884090320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884090128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884091088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884090512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884088592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884092048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884091280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884092432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884089744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884091472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884090704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884092816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884091856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884091664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884093200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884093008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884093968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884093392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884092240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884094160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884093584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884094928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884094352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884093776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884095888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884095120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884096272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884092624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884095312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884094544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884096656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884095696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884095504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884097040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884096848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884097808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884097232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884096080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884098000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884097424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884098768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884098192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884097616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884099728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884098960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884100112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884096464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884099152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884098384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884100496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884099536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884099920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884100688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884099344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884101456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884100880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884100304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884101648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884101072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884102416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884101840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884101264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884103376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884102608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884103760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884098576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884102800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884102032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884104144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884103184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884102992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884103568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884104336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884104528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693884103952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897425360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897425744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897425552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897426512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897425936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897425168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897427472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897426704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897427856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897424976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897426896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897426128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897428240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897427280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897427088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897428624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897428432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897429392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897428816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897427664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897429584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897429008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897430352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897429776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897429200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897431312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897430544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897431696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897428048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897430736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897429968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897432080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897431120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897430928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897432464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897432272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897433232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897432656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897431504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897433424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897432848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897434192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897433616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897433040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897435152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897434384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897435536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897431888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897434576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897433808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897435920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897434960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897434768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897436304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897436112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897437072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897436496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897435344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897437264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897436688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897438032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897437456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897436880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897438992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897438224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897439376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897435728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897438416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897437648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897439760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897438800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897439184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897439952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897438608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897440720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897440144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897439568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897437840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897440528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897441104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897440336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693897440912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963158928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963158352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963159312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963157968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963158736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963158160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963159696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963157776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963158544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963160080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963159888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963160848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963160272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963159120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963161040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963160464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963161808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963161232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963162768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963162000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963163152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963159504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963162192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963161424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963163536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963162576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963162384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963163920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963163728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963164688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963164112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963162960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963164880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963164304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963165648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963165072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963164496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963166608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963165840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963166992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963163344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963166032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963165264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963167376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963166416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963166224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963167760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963167568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963168528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963167952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963166800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963168720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963168144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963169488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963168912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963168336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963170448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963169680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963170832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963167184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963169872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963169104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963171216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963170256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963170064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963171600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963171408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963172368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963171792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963170640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963172560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963171984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963173328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963172752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963172176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963173712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963171024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963173136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963173520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976986640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976986256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693963172944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976985680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976986448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976987216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976987024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976987984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976987408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976985872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976988176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976987600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976988944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976988368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976987792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976989904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976989136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976990288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976986832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976989328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976988560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976990672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976989712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976989520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976991056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976990864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976991824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976991248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976990096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976992016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976991440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976992784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976992208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976991632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976993744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976992976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976994128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976990480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976993168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976992400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976994512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976993552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976993360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976994896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976994704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976995664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976995088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976995856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976996816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976996240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1693976997584: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ TFLite model saved to: c:\Users\SAHAN\Desktop\CNN\Models\efficientnet_quantized.tflite
# ✅ History saved to: c:\Users\SAHAN\Desktop\CNN\Models\training_history_efficientnet.pickle
